# %%
# Imports
import twint
import nest_asyncio
import numpy as np
import pandas as pa
import sklearn as sk
import keras 
import tensorflow as tf
import json
from pandas_datareader import data
from datetime import datetime
from datetime import timedelta  
from pandas.tseries.holiday import USFederalHolidayCalendar
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler

import re
import string

# NLP Packages
import nltk
from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.tokenize import word_tokenize

nltk.download('punkt')
nltk.download('vader_lexicon')
nltk.download('stopwords')

# This ensures the twint loop can run in jupyter notebook, no need to understand it
nest_asyncio.apply()
pa.set_option('display.max_colwidth', None)
# Out:
# [nltk_data] Downloading package punkt to /Users/Roy/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/Roy/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/Roy/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Predetermined Parameters
user = "michaeljburry"
tckr = "GME"

# %%
# Use twint to grab tweets and put into pandas dataframe
c = twint.Config()

c.Username = user
# I don't think the following line is neccessary as inputting to pandas gives us all columns by default
c.Custom["tweet"] = ["id", "username", "created_at", "username", "mentions" , "replies_count", "retweets_count", "likes_count", "hashtags", "tweet"]
c.Pandas = True

twint.run.Search(c)

Tweets_df = twint.storage.panda.Tweets_df
# Out:
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.

# %%
# Show dataframe
Tweets_df.sort_values(['date'], ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-47227843cf52> in <module>
#       1 # Show dataframe
# ----> 2 Tweets_df.sort_values(['date'], ascending=False)
#
# ~/opt/anaconda3/envs/tensorflow_env/lib/python3.7/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    5291
#    5292             by = by[0]
# -> 5293             k = self._get_label_or_level_values(by, axis=axis)
#    5294
#    5295             # need to rewrap column in Series to apply key function
#
# ~/opt/anaconda3/envs/tensorflow_env/lib/python3.7/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1558             values = self.axes[axis].get_level_values(key)._values
#    1559         else:
# -> 1560             raise KeyError(key)
#    1561
#    1562         # Check for duplicates
#
# KeyError: 'date'

# %%
from beeply import notes
mybeep = notes.beeps()
mybeep.hear('C',2000)

# %%
#  Show columns of dataframe
data_cols = Tweets_df.columns  
    
# display  
data_cols
# Out:
# Index(['id', 'conversation_id', 'created_at', 'date', 'timezone', 'place',
#        'tweet', 'language', 'hashtags', 'cashtags', 'user_id', 'user_id_str',
#        'username', 'name', 'day', 'hour', 'link', 'urls', 'photos', 'video',
#        'thumbnail', 'retweet', 'nlikes', 'nreplies', 'nretweets', 'quote_url',
#        'search', 'near', 'geo', 'source', 'user_rt_id', 'user_rt',
#        'retweet_id', 'reply_to', 'retweet_date', 'translate', 'trans_src',
#        'trans_dest'],
#       dtype='object')

# %%
# Get rid of tweets that are just replies (debatable for futre, we can test)
inds = []
col = Tweets_df['reply_to']
for i in range(Tweets_df.shape[0]):
    x = col[i]
    if x:
        inds.append(i)
# print(inds)
Tweets_df = Tweets_df.drop(inds, inplace = False)
Tweets_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-d6341af7988a> in <module>
#       4 for i in range(Tweets_df.shape[0]):
#       5     x = col[i]
# ----> 6     if x['user_id'] is not None:
#       7         inds.append(i)
#       8 # print(inds)
#
# TypeError: list indices must be integers or slices, not str

# %%
# Remove undesirable columns
rems = ['id', 'conversation_id', 'created_at', 'timezone', 'place',
       'language', 'user_id',
       'username', 'name', 'day', 'hour', 'urls', 'photos', 'video',
       'thumbnail', 'quote_url', 'search',
       'near', 'geo', 'source', 'reply_to', 'translate', 'trans_src',
       'trans_dest', 'link', 'user_id_str', 'cashtags']
Rem_Cols = Tweets_df.drop(rems, inplace = False, axis=1)
Rem_Cols.reset_index(drop=True, inplace=True)
Rem_Cols
# Out:
#                       date  \
# 0      2020-11-06 01:10:41
# 1      2020-11-06 00:55:31
# 2      2020-11-05 17:39:34
# 3      2020-11-05 04:31:58
# 4      2020-11-05 02:59:44
# ...                    ...
# 11317  2011-12-03 03:22:07
# 11318  2011-12-03 03:20:28
# 11319  2011-12-01 05:29:04
# 11320  2011-12-01 04:55:11
# 11321  2010-06-04 14:31:57
#
#                                                                                                                                                tweet  \
# 0                                                                                                                    420 is ten times better than 42
# 1                                                                                                                                                  🤗
# 2                                                                     @LinusTech @SpaceXStarlink @SpaceX Awaiting approval from Canadian authorities
# 3                              Recruiting ace engineers for Giga Berlin! Will interview in person tomorrow on site. Send resume to 25Guns@Tesla.com.
# 4                                                                                         @Chad_Hurley @realDonaldTrump @kanyewest Stop being a chad
# ...                                                                                                                                              ...
# 11317                                                                                                              That was a total non sequitur btw
# 11318       Great Voltaire quote, arguably better than Twain. Hearing news of his own death, Voltaire replied the reports were true, only premature.
# 11319                         I made the volume on the Model S  http://t.co/wMCnT53M go to 11.  Now I just need to work in a miniature Stonehenge...
# 11320  Went to Iceland on Sat to ride bumper cars on ice!  No, not the country, Vlad's rink in Van Nuys. Awesome family fun :)  http://t.co/rBQXJ9IT
# 11321                                                   Please ignore prior tweets, as that was someone pretending to be me :)  This is actually me.
#
#       hashtags  nlikes  nreplies  nretweets
# 0           []  103305      4467      11110
# 1           []   20201       780        435
# 2           []   11665       270        186
# 3           []   85675      2939       5312
# 4           []    2457       114         80
# ...        ...     ...       ...        ...
# 11317       []      10         2          4
# 11318       []      30         2         25
# 11319       []      57        15          8
# 11320       []     168        17         15
# 11321       []     708        87        144
#
# [11322 rows x 6 columns]

# %%
# Get stock data in range we will be using (calling yahoo once for a set of data that contains unwated values is far more efficient, trust me)
col = Rem_Cols['date']
# print(col)
end1 = (datetime.strptime(col[0], '%Y-%m-%d %H:%M:%S') + timedelta(days=3)).date()
start1 = (datetime.strptime(col[Rem_Cols.shape[0]-1], '%Y-%m-%d %H:%M:%S') + timedelta(days=-7)).date()

end = (datetime.strptime(col[0], '%Y-%m-%d %H:%M:%S') + timedelta(days=3)).date().strftime('%Y-%m-%d')
start = (datetime.strptime(col[Rem_Cols.shape[0]-1], '%Y-%m-%d %H:%M:%S') + timedelta(days=-7)).date().strftime('%Y-%m-%d')
panel_data = data.DataReader(tckr, 'yahoo', start, end)["Adj Close"]

inds = []
keys = panel_data.keys()
col = Rem_Cols['date']
for i in range(Rem_Cols.shape[0]):
    x = col[i]
    # print(datetime.strptime(x, '%Y-%m-%d %H:%M:%S') < keys[0])
    if (datetime.strptime(x, '%Y-%m-%d %H:%M:%S') < keys[0] or datetime.strptime(x, '%Y-%m-%d %H:%M:%S') > (datetime.today() + timedelta(days=-3))):
        inds.append(i)
tweets = Rem_Cols.drop(inds, inplace = False, axis=0)
# print(panel_data[end])
tweets.reset_index(drop=True, inplace=True)
tweets
# Out:
#                       date  \
# 0      2020-11-03 13:19:08
# 1      2020-11-03 10:10:08
# 2      2020-11-03 10:03:24
# 3      2020-11-03 09:59:17
# 4      2020-11-03 09:53:45
# ...                    ...
# 11309  2011-12-03 22:33:52
# 11310  2011-12-03 03:22:07
# 11311  2011-12-03 03:20:28
# 11312  2011-12-01 05:29:04
# 11313  2011-12-01 04:55:11
#
#                                                                                                                                                                                                                                                                                                                        tweet  \
# 0                                                                                                                                                                                                                                       @jtrevorchapman Yeah, that will be relatively easy, as so few users out in the ocean
# 1                                                                               @ICannot_Enough @ZainRaz4 @vincent13031925 @JonErlichman Yes, although I didn’t expect the stock to rise so much so soon. The reason for the stock options is that they’re needed to help pay for humanity to get to Mars in 10 to 20 years.
# 2                                                                                                                                         @FutureJurvetson @PPathole Super appreciate your support, Steve! That convertible loan gave us 6 months of runway. Fortunately, Daimler invested $50M in May 2009, 5 months later.
# 3                                                                                                                    @ZainRaz4 @vincent13031925 @JonErlichman Closest we got was about a month. The Model 3 ramp was extreme stress &amp; pain for a long time — from mid 2017 to mid 2019. Production &amp; logistics hell.
# 4      @vincent13031925 @JonErlichman I put in my last money, even though I thought we would still fail. But, it was either that or certain death for Tesla. Extremely difficult to raise money for an electric car startup (considered super quirky back then), while stalwarts like GM &amp; Chrysler were going bankrupt.
# ...                                                                                                                                                                                                                                                                                                                      ...
# 11309                                                                                                                                                                                                                                          Am reading a great biography of Ben Franklin by Isaacson. Highly recommended.
# 11310                                                                                                                                                                                                                                                                                      That was a total non sequitur btw
# 11311                                                                                                                                                                               Great Voltaire quote, arguably better than Twain. Hearing news of his own death, Voltaire replied the reports were true, only premature.
# 11312                                                                                                                                                                                                 I made the volume on the Model S  http://t.co/wMCnT53M go to 11.  Now I just need to work in a miniature Stonehenge...
# 11313                                                                                                                                                                          Went to Iceland on Sat to ride bumper cars on ice!  No, not the country, Vlad's rink in Van Nuys. Awesome family fun :)  http://t.co/rBQXJ9IT
#
#       hashtags  nlikes  nreplies  nretweets
# 0           []    1908       126         53
# 1           []    3774       229        232
# 2           []    1875        65         74
# 3           []    2412       115        107
# 4           []    6070       232        370
# ...        ...     ...       ...        ...
# 11309       []      55         9         10
# 11310       []      10         2          4
# 11311       []      30         2         25
# 11312       []      57        15          8
# 11313       []     168        17         15
#
# [11314 rows x 6 columns]

# %%
# Acquire percent change of the closing prices surrounding each tweet and add to dataframe
percs = []
col = tweets['date']
for i in range(tweets.shape[0]):
    x = col[i]
    end_date = datetime.strptime(x, '%Y-%m-%d %H:%M:%S')

    if (end_date.hour > 15):
        end_date = end_date + timedelta(days=1)
    start_date = end_date + timedelta(days=-1)

    while (end_date.date() not in panel_data) or (end_date.weekday() == 5) or (end_date.weekday() == 6):
        end_date = end_date + timedelta(days=1) 
    while (start_date.date() not in panel_data) or (start_date.weekday() == 5) or (start_date.weekday() == 6):
        start_date = start_date + timedelta(days=-1)
    end_date = end_date.date().strftime('%Y-%m-%d')
    start_date = start_date.date().strftime('%Y-%m-%d')
    percs.append((panel_data[end_date] - panel_data[start_date])/panel_data[start_date])

tweets['Percent Change'] = percs
tweets
# Out:
#                       date  \
# 0      2020-11-03 13:19:08
# 1      2020-11-03 10:10:08
# 2      2020-11-03 10:03:24
# 3      2020-11-03 09:59:17
# 4      2020-11-03 09:53:45
# ...                    ...
# 11309  2011-12-03 22:33:52
# 11310  2011-12-03 03:22:07
# 11311  2011-12-03 03:20:28
# 11312  2011-12-01 05:29:04
# 11313  2011-12-01 04:55:11
#
#                                                                                                                                                                                                                                                                                                                        tweet  \
# 0                                                                                                                                                                                                                                       @jtrevorchapman Yeah, that will be relatively easy, as so few users out in the ocean
# 1                                                                               @ICannot_Enough @ZainRaz4 @vincent13031925 @JonErlichman Yes, although I didn’t expect the stock to rise so much so soon. The reason for the stock options is that they’re needed to help pay for humanity to get to Mars in 10 to 20 years.
# 2                                                                                                                                         @FutureJurvetson @PPathole Super appreciate your support, Steve! That convertible loan gave us 6 months of runway. Fortunately, Daimler invested $50M in May 2009, 5 months later.
# 3                                                                                                                    @ZainRaz4 @vincent13031925 @JonErlichman Closest we got was about a month. The Model 3 ramp was extreme stress &amp; pain for a long time — from mid 2017 to mid 2019. Production &amp; logistics hell.
# 4      @vincent13031925 @JonErlichman I put in my last money, even though I thought we would still fail. But, it was either that or certain death for Tesla. Extremely difficult to raise money for an electric car startup (considered super quirky back then), while stalwarts like GM &amp; Chrysler were going bankrupt.
# ...                                                                                                                                                                                                                                                                                                                      ...
# 11309                                                                                                                                                                                                                                          Am reading a great biography of Ben Franklin by Isaacson. Highly recommended.
# 11310                                                                                                                                                                                                                                                                                      That was a total non sequitur btw
# 11311                                                                                                                                                                               Great Voltaire quote, arguably better than Twain. Hearing news of his own death, Voltaire replied the reports were true, only premature.
# 11312                                                                                                                                                                                                 I made the volume on the Model S  http://t.co/wMCnT53M go to 11.  Now I just need to work in a miniature Stonehenge...
# 11313                                                                                                                                                                          Went to Iceland on Sat to ride bumper cars on ice!  No, not the country, Vlad's rink in Van Nuys. Awesome family fun :)  http://t.co/rBQXJ9IT
#
#       hashtags  nlikes  nreplies  nretweets  Percent Change
# 0           []    1908       126         53        0.058400
# 1           []    3774       229        232        0.058400
# 2           []    1875        65         74        0.058400
# 3           []    2412       115        107        0.058400
# 4           []    6070       232        370        0.058400
# ...        ...     ...       ...        ...             ...
# 11309       []      55         9         10        0.033634
# 11310       []      10         2          4        0.033634
# 11311       []      30         2         25        0.033634
# 11312       []      57        15          8       -0.004276
# 11313       []     168        17         15       -0.004276
#
# [11314 rows x 7 columns]

# %%
# Tweet cleaning helper methods
def cleanTxt(text):
    # Get rid of @s, links, Hashtag, and RT
    text = re.sub(r'@[A-Za-z0-9]+', '', str(text))
    text = re.sub(r'#', '', str(text))
    text = re.sub(r'RT[\s]+', '', str(text))
    text = re.sub(r'https?:\/\/\S+', '', str(text))

    # Lowercase and remove punctuation
    text = text.lower()
    text = text.translate(str.maketrans('', '', string.punctuation))

    tokens = word_tokenize(text)
    tokens_without_sw = [word for word in tokens if word not in stopwords.words()]
    return " ".join(tokens_without_sw)

# %%
tweets['tweet'] = tweets['tweet'].apply(cleanTxt)
# tweets['tweet'] = tweets['tweet'].apply(removeStopWords)
tweets
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-508-99fed03a7d04> in <module>
# ----> 1 tweets['tweet'] = tweets['tweet'].apply(cleanTxt)
#       2 # tweets['tweet'] = tweets['tweet'].apply(removeStopWords)
#       3 tweets
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-507-6ad843d7617d> in cleanTxt(text)
#      12
#      13     tokens = word_tokenize(text)
# ---> 14     tokens_without_sw = [word for word in tokens if word not in stopwords.words()]
#      15     return " ".join(tokens_without_sw)
#
# <ipython-input-507-6ad843d7617d> in <listcomp>(.0)
#      12
#      13     tokens = word_tokenize(text)
# ---> 14     tokens_without_sw = [word for word in tokens if word not in stopwords.words()]
#      15     return " ".join(tokens_without_sw)
#
# ~\AppData\Roaming\Python\Python37\site-packages\nltk\corpus\reader\wordlist.py in words(self, fileids, ignore_lines_startswith)
#      21         return [
#      22             line
# ---> 23             for line in line_tokenize(self.raw(fileids))
#      24             if not line.startswith(ignore_lines_startswith)
#      25         ]
#
# ~\AppData\Roaming\Python\Python37\site-packages\nltk\corpus\reader\wordlist.py in raw(self, fileids)
#      30         elif isinstance(fileids, str):
#      31             fileids = [fileids]
# ---> 32         return concat([self.open(f).read() for f in fileids])
#      33
#      34
#
# ~\AppData\Roaming\Python\Python37\site-packages\nltk\corpus\reader\wordlist.py in <listcomp>(.0)
#      30         elif isinstance(fileids, str):
#      31             fileids = [fileids]
# ---> 32         return concat([self.open(f).read() for f in fileids])
#      33
#      34
#
# ~\AppData\Roaming\Python\Python37\site-packages\nltk\corpus\reader\api.py in open(self, file)
#     206         """
#     207         encoding = self.encoding(file)
# --> 208         stream = self._root.join(file).open(encoding)
#     209         return stream
#     210
#
# ~\AppData\Roaming\Python\Python37\site-packages\nltk\data.py in join(self, fileid)
#     335     def join(self, fileid):
#     336         _path = os.path.join(self._path, fileid)
# --> 337         return FileSystemPathPointer(_path)
#     338
#     339     def __repr__(self):
#
# ~\AppData\Roaming\Python\Python37\site-packages\nltk\compat.py in _decorator(*args, **kwargs)
#      39     def _decorator(*args, **kwargs):
#      40         args = (args[0], add_py3_data(args[1])) + args[2:]
# ---> 41         return init_func(*args, **kwargs)
#      42
#      43     return wraps(init_func)(_decorator)
#
# ~\AppData\Roaming\Python\Python37\site-packages\nltk\data.py in __init__(self, _path)
#     312
#     313         _path = os.path.abspath(_path)
# --> 314         if not os.path.exists(_path):
#     315             raise IOError("No such file or directory: %r" % _path)
#     316         self._path = _path
#
# ~\AppData\Local\Programs\Python\Python37\lib\genericpath.py in exists(path)
#      17     """Test whether a path exists.  Returns False for broken symbolic links"""
#      18     try:
# ---> 19         os.stat(path)
#      20     except OSError:
#      21         return False
#
# KeyboardInterrupt:

# %%
# Sentiment score helpers
def sentimentScoreNeg(text):
    score = SentimentIntensityAnalyzer().polarity_scores(text)
    return score['neg']

def sentimentScorePos(text):
    score = SentimentIntensityAnalyzer().polarity_scores(text)
    return score['pos']

def sentimentScoreNeu(text):
    score = SentimentIntensityAnalyzer().polarity_scores(text)
    return score['neu']
tweets
# Out:
#                       date  \
# 0      2020-11-03 13:19:08
# 1      2020-11-03 10:10:08
# 2      2020-11-03 10:03:24
# 3      2020-11-03 09:59:17
# 4      2020-11-03 09:53:45
# ...                    ...
# 11309  2011-12-03 22:33:52
# 11310  2011-12-03 03:22:07
# 11311  2011-12-03 03:20:28
# 11312  2011-12-01 05:29:04
# 11313  2011-12-01 04:55:11
#
#                                                                                                                                                                                                                                                                                                                        tweet  \
# 0                                                                                                                                                                                                                                       @jtrevorchapman Yeah, that will be relatively easy, as so few users out in the ocean
# 1                                                                               @ICannot_Enough @ZainRaz4 @vincent13031925 @JonErlichman Yes, although I didn’t expect the stock to rise so much so soon. The reason for the stock options is that they’re needed to help pay for humanity to get to Mars in 10 to 20 years.
# 2                                                                                                                                         @FutureJurvetson @PPathole Super appreciate your support, Steve! That convertible loan gave us 6 months of runway. Fortunately, Daimler invested $50M in May 2009, 5 months later.
# 3                                                                                                                    @ZainRaz4 @vincent13031925 @JonErlichman Closest we got was about a month. The Model 3 ramp was extreme stress &amp; pain for a long time — from mid 2017 to mid 2019. Production &amp; logistics hell.
# 4      @vincent13031925 @JonErlichman I put in my last money, even though I thought we would still fail. But, it was either that or certain death for Tesla. Extremely difficult to raise money for an electric car startup (considered super quirky back then), while stalwarts like GM &amp; Chrysler were going bankrupt.
# ...                                                                                                                                                                                                                                                                                                                      ...
# 11309                                                                                                                                                                                                                                          Am reading a great biography of Ben Franklin by Isaacson. Highly recommended.
# 11310                                                                                                                                                                                                                                                                                      That was a total non sequitur btw
# 11311                                                                                                                                                                               Great Voltaire quote, arguably better than Twain. Hearing news of his own death, Voltaire replied the reports were true, only premature.
# 11312                                                                                                                                                                                                 I made the volume on the Model S  http://t.co/wMCnT53M go to 11.  Now I just need to work in a miniature Stonehenge...
# 11313                                                                                                                                                                          Went to Iceland on Sat to ride bumper cars on ice!  No, not the country, Vlad's rink in Van Nuys. Awesome family fun :)  http://t.co/rBQXJ9IT
#
#       hashtags  nlikes  nreplies  nretweets  Percent Change
# 0           []    1908       126         53        0.058400
# 1           []    3774       229        232        0.058400
# 2           []    1875        65         74        0.058400
# 3           []    2412       115        107        0.058400
# 4           []    6070       232        370        0.058400
# ...        ...     ...       ...        ...             ...
# 11309       []      55         9         10        0.033634
# 11310       []      10         2          4        0.033634
# 11311       []      30         2         25        0.033634
# 11312       []      57        15          8       -0.004276
# 11313       []     168        17         15       -0.004276
#
# [11314 rows x 7 columns]

# %%
tweets['NegScore'] = tweets['tweet'].apply(sentimentScoreNeg)
tweets['NeuScore'] = tweets['tweet'].apply(sentimentScoreNeu)
tweets['PosScore'] = tweets['tweet'].apply(sentimentScorePos)
tweets
# Out:
#                       date  \
# 0      2020-11-03 13:19:08
# 1      2020-11-03 10:10:08
# 2      2020-11-03 10:03:24
# 3      2020-11-03 09:59:17
# 4      2020-11-03 09:53:45
# ...                    ...
# 11309  2011-12-03 22:33:52
# 11310  2011-12-03 03:22:07
# 11311  2011-12-03 03:20:28
# 11312  2011-12-01 05:29:04
# 11313  2011-12-01 04:55:11
#
#                                                                                                                                                                                                                                                                                                                        tweet  \
# 0                                                                                                                                                                                                                                       @jtrevorchapman Yeah, that will be relatively easy, as so few users out in the ocean
# 1                                                                               @ICannot_Enough @ZainRaz4 @vincent13031925 @JonErlichman Yes, although I didn’t expect the stock to rise so much so soon. The reason for the stock options is that they’re needed to help pay for humanity to get to Mars in 10 to 20 years.
# 2                                                                                                                                         @FutureJurvetson @PPathole Super appreciate your support, Steve! That convertible loan gave us 6 months of runway. Fortunately, Daimler invested $50M in May 2009, 5 months later.
# 3                                                                                                                    @ZainRaz4 @vincent13031925 @JonErlichman Closest we got was about a month. The Model 3 ramp was extreme stress &amp; pain for a long time — from mid 2017 to mid 2019. Production &amp; logistics hell.
# 4      @vincent13031925 @JonErlichman I put in my last money, even though I thought we would still fail. But, it was either that or certain death for Tesla. Extremely difficult to raise money for an electric car startup (considered super quirky back then), while stalwarts like GM &amp; Chrysler were going bankrupt.
# ...                                                                                                                                                                                                                                                                                                                      ...
# 11309                                                                                                                                                                                                                                          Am reading a great biography of Ben Franklin by Isaacson. Highly recommended.
# 11310                                                                                                                                                                                                                                                                                      That was a total non sequitur btw
# 11311                                                                                                                                                                               Great Voltaire quote, arguably better than Twain. Hearing news of his own death, Voltaire replied the reports were true, only premature.
# 11312                                                                                                                                                                                                 I made the volume on the Model S  http://t.co/wMCnT53M go to 11.  Now I just need to work in a miniature Stonehenge...
# 11313                                                                                                                                                                          Went to Iceland on Sat to ride bumper cars on ice!  No, not the country, Vlad's rink in Van Nuys. Awesome family fun :)  http://t.co/rBQXJ9IT
#
#       hashtags  nlikes  nreplies  nretweets  Percent Change  NegScore  \
# 0           []    1908       126         53        0.058400     0.000
# 1           []    3774       229        232        0.058400     0.032
# 2           []    1875        65         74        0.058400     0.000
# 3           []    2412       115        107        0.058400     0.284
# 4           []    6070       232        370        0.058400     0.218
# ...        ...     ...       ...        ...             ...       ...
# 11309       []      55         9         10        0.033634     0.000
# 11310       []      10         2          4        0.033634     0.000
# 11311       []      30         2         25        0.033634     0.186
# 11312       []      57        15          8       -0.004276     0.000
# 11313       []     168        17         15       -0.004276     0.065
#
#        NeuScore  PosScore
# 0         0.718     0.282
# 1         0.845     0.123
# 2         0.686     0.314
# 3         0.716     0.000
# 4         0.648     0.134
# ...         ...       ...
# 11309     0.592     0.408
# 11310     1.000     0.000
# 11311     0.505     0.309
# 11312     1.000     0.000
# 11313     0.620     0.315
#
# [11314 rows x 10 columns]

# %%
# Determine if tweet is about tesla
def isAboutTesla(text):
    flag = 0
    myList = ["Tesla" in text, "tesla" in text, "TESLA" in text, "TSLA" in text]

    if any(myList):
        flag = .3

    return flag

# %%
tweets['TeslaFlag'] = tweets['tweet'].apply(isAboutTesla)
tweets
# Out:
#                       date  \
# 0      2020-11-03 13:19:08
# 1      2020-11-03 10:10:08
# 2      2020-11-03 10:03:24
# 3      2020-11-03 09:59:17
# 4      2020-11-03 09:53:45
# ...                    ...
# 11309  2011-12-03 22:33:52
# 11310  2011-12-03 03:22:07
# 11311  2011-12-03 03:20:28
# 11312  2011-12-01 05:29:04
# 11313  2011-12-01 04:55:11
#
#                                                                                                                                                                                                                                                                                                                        tweet  \
# 0                                                                                                                                                                                                                                       @jtrevorchapman Yeah, that will be relatively easy, as so few users out in the ocean
# 1                                                                               @ICannot_Enough @ZainRaz4 @vincent13031925 @JonErlichman Yes, although I didn’t expect the stock to rise so much so soon. The reason for the stock options is that they’re needed to help pay for humanity to get to Mars in 10 to 20 years.
# 2                                                                                                                                         @FutureJurvetson @PPathole Super appreciate your support, Steve! That convertible loan gave us 6 months of runway. Fortunately, Daimler invested $50M in May 2009, 5 months later.
# 3                                                                                                                    @ZainRaz4 @vincent13031925 @JonErlichman Closest we got was about a month. The Model 3 ramp was extreme stress &amp; pain for a long time — from mid 2017 to mid 2019. Production &amp; logistics hell.
# 4      @vincent13031925 @JonErlichman I put in my last money, even though I thought we would still fail. But, it was either that or certain death for Tesla. Extremely difficult to raise money for an electric car startup (considered super quirky back then), while stalwarts like GM &amp; Chrysler were going bankrupt.
# ...                                                                                                                                                                                                                                                                                                                      ...
# 11309                                                                                                                                                                                                                                          Am reading a great biography of Ben Franklin by Isaacson. Highly recommended.
# 11310                                                                                                                                                                                                                                                                                      That was a total non sequitur btw
# 11311                                                                                                                                                                               Great Voltaire quote, arguably better than Twain. Hearing news of his own death, Voltaire replied the reports were true, only premature.
# 11312                                                                                                                                                                                                 I made the volume on the Model S  http://t.co/wMCnT53M go to 11.  Now I just need to work in a miniature Stonehenge...
# 11313                                                                                                                                                                          Went to Iceland on Sat to ride bumper cars on ice!  No, not the country, Vlad's rink in Van Nuys. Awesome family fun :)  http://t.co/rBQXJ9IT
#
#       hashtags  nlikes  nreplies  nretweets  Percent Change  NegScore  \
# 0           []    1908       126         53        0.058400     0.000
# 1           []    3774       229        232        0.058400     0.032
# 2           []    1875        65         74        0.058400     0.000
# 3           []    2412       115        107        0.058400     0.284
# 4           []    6070       232        370        0.058400     0.218
# ...        ...     ...       ...        ...             ...       ...
# 11309       []      55         9         10        0.033634     0.000
# 11310       []      10         2          4        0.033634     0.000
# 11311       []      30         2         25        0.033634     0.186
# 11312       []      57        15          8       -0.004276     0.000
# 11313       []     168        17         15       -0.004276     0.065
#
#        NeuScore  PosScore  TeslaFlag
# 0         0.718     0.282        0.0
# 1         0.845     0.123        0.0
# 2         0.686     0.314        0.0
# 3         0.716     0.000        0.0
# 4         0.648     0.134        0.3
# ...         ...       ...        ...
# 11309     0.592     0.408        0.0
# 11310     1.000     0.000        0.0
# 11311     0.505     0.309        0.0
# 11312     1.000     0.000        0.0
# 11313     0.620     0.315        0.0
#
# [11314 rows x 11 columns]

# %%
# for i in range(tweets.shape[0]):
#     print(tweets['tweet'][i])
cleaned_tweets = tweets['tweet'].apply(cleanTxt)
tweets.drop(['date', 'tweet', 'hashtags'], inplace = True, axis=1)
tweets
# Out:
#        nlikes  nreplies  nretweets  Percent Change  NegScore  NeuScore  \
# 0        1908       126         53        0.058400     0.000     0.718
# 1        3774       229        232        0.058400     0.032     0.845
# 2        1875        65         74        0.058400     0.000     0.686
# 3        2412       115        107        0.058400     0.284     0.716
# 4        6070       232        370        0.058400     0.218     0.648
# ...       ...       ...        ...             ...       ...       ...
# 11309      55         9         10        0.033634     0.000     0.592
# 11310      10         2          4        0.033634     0.000     1.000
# 11311      30         2         25        0.033634     0.186     0.505
# 11312      57        15          8       -0.004276     0.000     1.000
# 11313     168        17         15       -0.004276     0.065     0.620
#
#        PosScore  TeslaFlag
# 0         0.282        0.0
# 1         0.123        0.0
# 2         0.314        0.0
# 3         0.000        0.0
# 4         0.134        0.3
# ...         ...        ...
# 11309     0.408        0.0
# 11310     0.000        0.0
# 11311     0.309        0.0
# 11312     0.000        0.0
# 11313     0.315        0.0
#
# [11314 rows x 8 columns]

# %%
cleaned_tweets
# Out:
# 0                                                                                                                                                                                      yeah relatively easy users ocean
# 1                                                                                                enough yes although ’ expect stock rise much soon reason stock options ’ needed help pay humanity get mars 10 20 years
# 2                                                                                      super appreciate support steve convertible loan gave us 6 months runway fortunately daimler invested 50m may 2009 5 months later
# 3                                                                                                    closest got month model 3 ramp extreme stress amp pain long time — mid 2017 mid 2019 production amp logistics hell
# 4        put last money even though thought would still fail either certain death tesla extremely difficult raise money electric car startup considered super quirky back stalwarts like gm amp chrysler going bankrupt
#                                                                                                               ...
# 11309                                                                                                                                                      reading great biography franklin isaacson highly recommended
# 11310                                                                                                                                                                                                total sequitur btw
# 11311                                                                                                             great voltaire quote arguably better twain hearing news death voltaire replied reports true premature
# 11312                                                                                                                                                            made volume model go 11 need work miniature stonehenge
# 11313                                                                                                                                  went iceland sat ride bumper cars ice country vlads rink nuys awesome family fun
# Name: tweet, Length: 11314, dtype: object

# %%
# Create clear cut clusters for positive v negative change
def percChangeAssign(perc):
    if perc >= 0:
        return 1
    else:
        return 0

# %%
tweets_edit = tweets.copy()
tweets_edit['Percent Change'] = tweets_edit['Percent Change'].apply(percChangeAssign)
tweets
# Out:
#        nlikes  nreplies  nretweets  Percent Change  NegScore  NeuScore  \
# 0        1908       126         53        0.058400     0.000     0.718
# 1        3774       229        232        0.058400     0.032     0.845
# 2        1875        65         74        0.058400     0.000     0.686
# 3        2412       115        107        0.058400     0.284     0.716
# 4        6070       232        370        0.058400     0.218     0.648
# ...       ...       ...        ...             ...       ...       ...
# 11309      55         9         10        0.033634     0.000     0.592
# 11310      10         2          4        0.033634     0.000     1.000
# 11311      30         2         25        0.033634     0.186     0.505
# 11312      57        15          8       -0.004276     0.000     1.000
# 11313     168        17         15       -0.004276     0.065     0.620
#
#        PosScore  TeslaFlag
# 0         0.282        0.0
# 1         0.123        0.0
# 2         0.314        0.0
# 3         0.000        0.0
# 4         0.134        0.3
# ...         ...        ...
# 11309     0.408        0.0
# 11310     0.000        0.0
# 11311     0.309        0.0
# 11312     0.000        0.0
# 11313     0.315        0.0
#
# [11314 rows x 8 columns]

# %%
tweets_clust = tweets_edit.copy()
scaler = MinMaxScaler(feature_range=(0,1))
nlikes = scaler.fit_transform(tweets_clust['nlikes'].values.reshape(-1,1))
tweets_clust['nlikes'] = nlikes
nreplies = scaler.fit_transform(tweets_clust['nreplies'].values.reshape(-1,1))
tweets_clust['nreplies'] = nreplies
nretweets = scaler.fit_transform(tweets_clust['nretweets'].values.reshape(-1,1))
tweets_clust['nretweets'] = nretweets
scaler = MinMaxScaler(feature_range=(0,1))
neg = scaler.fit_transform(tweets_clust['NegScore'].values.reshape(-1,1))
tweets_clust['NegScore'] = neg
neu = scaler.fit_transform(tweets_clust['NeuScore'].values.reshape(-1,1))
tweets_clust['NeuScore'] = neu
pos = scaler.fit_transform(tweets_clust['PosScore'].values.reshape(-1,1))
tweets_clust['PosScore'] = pos
tweets_clust
# Out:
#          nlikes  nreplies  nretweets  Percent Change  NegScore  NeuScore  \
# 0      0.001160  0.002642   0.000142               1     0.000     0.718
# 1      0.002295  0.004801   0.000620               1     0.032     0.845
# 2      0.001140  0.001363   0.000198               1     0.000     0.686
# 3      0.001466  0.002411   0.000286               1     0.284     0.716
# 4      0.003691  0.004864   0.000990               1     0.218     0.648
# ...         ...       ...        ...             ...       ...       ...
# 11309  0.000033  0.000189   0.000027               1     0.000     0.592
# 11310  0.000005  0.000042   0.000011               1     0.000     1.000
# 11311  0.000018  0.000042   0.000067               1     0.186     0.505
# 11312  0.000034  0.000314   0.000021               0     0.000     1.000
# 11313  0.000102  0.000356   0.000040               0     0.065     0.620
#
#        PosScore  TeslaFlag
# 0         0.282        0.0
# 1         0.123        0.0
# 2         0.314        0.0
# 3         0.000        0.0
# 4         0.134        0.3
# ...         ...        ...
# 11309     0.408        0.0
# 11310     0.000        0.0
# 11311     0.309        0.0
# 11312     0.000        0.0
# 11313     0.315        0.0
#
# [11314 rows x 8 columns]

# %%
# Grab the "Answers"
answers = tweets_clust['Percent Change'].values
print(answers)
tweets_clust.drop(['Percent Change'], inplace = True, axis=1)
tweets_clust
# Out:
# [1 1 1 ... 1 0 0]
#          nlikes  nreplies  nretweets  NegScore  NeuScore  PosScore  TeslaFlag
# 0      0.001160  0.002642   0.000142     0.000     0.718     0.282        0.0
# 1      0.002295  0.004801   0.000620     0.032     0.845     0.123        0.0
# 2      0.001140  0.001363   0.000198     0.000     0.686     0.314        0.0
# 3      0.001466  0.002411   0.000286     0.284     0.716     0.000        0.0
# 4      0.003691  0.004864   0.000990     0.218     0.648     0.134        0.3
# ...         ...       ...        ...       ...       ...       ...        ...
# 11309  0.000033  0.000189   0.000027     0.000     0.592     0.408        0.0
# 11310  0.000005  0.000042   0.000011     0.000     1.000     0.000        0.0
# 11311  0.000018  0.000042   0.000067     0.186     0.505     0.309        0.0
# 11312  0.000034  0.000314   0.000021     0.000     1.000     0.000        0.0
# 11313  0.000102  0.000356   0.000040     0.065     0.620     0.315        0.0
#
# [11314 rows x 7 columns]

# %%
n_clusters = 6
# len(np.unique(y))

kmeans = KMeans(n_clusters=n_clusters, n_init=20, n_jobs=4)
# Train K-Means.
y_pred_kmeans = kmeans.fit(tweets_clust)
y_pred_kmeans = kmeans.predict(tweets_clust)
# Evaluate the K-Means clustering accuracy.
# metrics.acc(y, y_pred_kmeans)
num = 11313
print(y_pred_kmeans)
print(answers)
if n_clusters == 2:
    print(np.sum(y_pred_kmeans[0:num]))
    print(np.sum(answers[0:num]))
    print(sk.metrics.accuracy_score(answers[0:num], y_pred_kmeans[0:num]))
    print(sk.metrics.recall_score(answers[0:num], y_pred_kmeans[0:num]))
    print(sk.metrics.precision_score(answers[0:num], y_pred_kmeans[0:num]))
tweets_results = tweets.copy()
tweets_results['cluster'] = y_pred_kmeans
tweets_results
# Out:
# [4 4 1 ... 1 0 1]
# [1 1 1 ... 1 0 0]
#        nlikes  nreplies  nretweets  Percent Change  NegScore  NeuScore  \
# 0        1908       126         53        0.058400     0.000     0.718
# 1        3774       229        232        0.058400     0.032     0.845
# 2        1875        65         74        0.058400     0.000     0.686
# 3        2412       115        107        0.058400     0.284     0.716
# 4        6070       232        370        0.058400     0.218     0.648
# ...       ...       ...        ...             ...       ...       ...
# 11309      55         9         10        0.033634     0.000     0.592
# 11310      10         2          4        0.033634     0.000     1.000
# 11311      30         2         25        0.033634     0.186     0.505
# 11312      57        15          8       -0.004276     0.000     1.000
# 11313     168        17         15       -0.004276     0.065     0.620
#
#        PosScore  TeslaFlag  cluster
# 0         0.282        0.0        4
# 1         0.123        0.0        4
# 2         0.314        0.0        1
# 3         0.000        0.0        2
# 4         0.134        0.3        3
# ...         ...        ...      ...
# 11309     0.408        0.0        1
# 11310     0.000        0.0        0
# 11311     0.309        0.0        1
# 11312     0.000        0.0        0
# 11313     0.315        0.0        1
#
# [11314 rows x 9 columns]

# %%
clust_0 = tweets_results.loc[tweets_results['cluster'] == 0] 
inds = clust_0.index
print("")
print("")
print("")
print("")
print("Clust ", 0)
for j in inds:
    print(cleaned_tweets[j])
clusts = pa.DataFrame(data=clust_0.mean(axis=0))
for i in range(1,n_clusters):
    clust_i = tweets_results.loc[tweets_results['cluster'] == i] 
    inds = clust_i.index
    print("")
    print("")
    print("")
    print("")
    print("Clust ", i)
    for j in inds:
        print(cleaned_tweets[j])
    # clust_1 = tweets_results.loc[tweets_results['cluster'] == 1]
    # clust_2 = tweets_results.loc[tweets_results['cluster'] == 2] 
    # clust_3 = tweets_results.loc[tweets_results['cluster'] == 3]
    # clust_4 = tweets_results.loc[tweets_results['cluster'] == 4] 
    # clust_5 = tweets_results.loc[tweets_results['cluster'] == 5]
    # print("Cluster 0\n", clust_0.shape, "\n",clust_0.mean(axis=0))
    # print("Cluster 1\n", clust_1.shape, "\n",clust_1.mean(axis=0))
    # print("Cluster 2\n", clust_2.shape, "\n",clust_2.mean(axis=0))
    # print("Cluster 3\n", clust_3.shape, "\n",clust_3.mean(axis=0))
    # print("Cluster 4\n", clust_4.shape, "\n",clust_4.mean(axis=0))
    # print("Cluster 5\n", clust_5.shape, "\n",clust_5.mean(axis=0))
    
    clusts[i] = clust_i.mean(axis=0)
clusts
# Out:
# Clust  0
# arne canada norway next get us early beta
# several thousand starlink beta participation invitations going week
# close actual expected flight
# lockyer could excited new supercollider said considerably larger ’ think necessarily requires much incremental engineering
# penguin random house 😴 change random penguin🔥
#
# lord …
# minor
# … sweden still right zero deaths oct 29
# accurate
#
# 😉
# sci urf smōl
# long time
# might buy jack box footstool
# approximately lograte
# bot change setting “ combat ”
# little crane “ toy ”
# 🤣🤣
# jack box double duty sperm donor clinic — 👌
#
# bettern nothin ur 💰 back
# 💫 🛰
# testing covid license print money
# feed sigh … new supersonic jet time electric
# days ahead
# ’ boca every week maybe could talk given starship exactly subtle design clarification match people already see
# sanders working needs able fart cars command
# starship coming together
# price change pushed thursday next week applies us week clock start countries beta released fsd monthly rental available sometime next year
# smallseeming issue loss upper stage camera probably nothing serious standing reexamine whole vehicle case
# cold gas hot later
# mean got tiki bar …
# starship nosecone high bay amp tiki bar
# …
# gets orbit times
# fsd beta rollout happening tonight extremely slow amp cautious
# sweden zero deaths oct 15
# actually ’ neck …
# møtør trèndé
#
# 😢
# system autodelete old data automatically default
# 9 meter roughly 30 ft diameter
# less roomy 3 vacuum rocket engines added
# 🤘 illuminaughty 🤘
# knee deep
# graph appears upside
#
# even half amount ’ still big deal
# nafnlaus 🤣🤣
# exact art wall place stay boca chica
# sweden right
# stanley bass3d tiles mechanically attached
# stanley bass3d tiles hot side flaps tough problem sealing moving flap body joint without melting shredding seal
# norway leads world
# passed cryo proof
# 👍
# maybe flag mars
# meant say fixed latest wide release ’ need wait fsd
#
# mimecraft
# mass ratio liquid oxygen much denser liquid methane even latter cooled freezing point
# avoigt zimon looks tasty
# enough sandy munro understands engineering
# prototypes piece cake high volume production new technology extremely hard takes much longer people think climb production scurve ’ emphasize enough production far hard part
# expect make heavy use lfp medium range cars amp stationary storage
# berlin use 4680 cell structural battery pack amp front amp rear single piece castings new paint system lot new technology happen berlin means significant production risk fremont amp shanghai transition 2 years new tech proven
#
# ’ seeing notable differences yet think boosters could probably 100 reflights small composite helium tanks would need replaced maybe turbopump hot sections
# 4th flight amp landing booster
# 💯
#
# article wildly incorrect lithium battery costs factor 5 presently amp 10x longterm
# new spacex droneship called “ shortfall gravitas ”
# nothing escape gravity even black holes really tried
#
# ’ broad review launch site propulsion structures avionics range amp regulatory constraints weekend cape next week review hardware person
# exactly
# mbrown oh yeah starship update coming 3 weeks design coalesced presented actually flies orbit v10 almost changes
# average latency improve satellites launch directly frequently amp ground stations deployed ’ able put ground stations roofs server centers legacy internet latency zero
# ’ nextlevel
# 💰💩🤣
#
# light fast ’ think
# total market
# seven years sure 30m new fully electric vehicles year six years maybe five years possible unlikely extra year makes giant difference comes exponentials
# ’ cutting price model 3 25k referring future car smaller model 3
# kerle new version coming soon
#
# 🤣🤣
# checking
# species stood test time
# mostly 304l 301 broke 301 304 interface sn9 304 ’ making tweaks 304 alloy mixture
# need enough height test body flaps amp drawing propellant headers vs main tanks several flights confirm working well add heat shield amp go high mach
# first flight 15km 50000 ft
# nosecone amp front flaps next week sn9 next month
# starship sn8 rear body flaps
#
# nafnlaus exactly
# sandy munro understands engineering
# turns mostly press letter amp 💩 typewriter 🤣
# centaur bow obviously
# 9007mm
# 🖤 ur
#
# preburners ignite main chamber
# prediction probability inaccurate
# genetic engineering slow unless use synthetic virus
# ’ predict
# 107 expansion ratio little bit flow separation towards nozzle
# maybe …
# probably
# cybertruck atv roadster amp semi r
# enough little year challenging year ’ ever probably next years
# ’ right maybe little faster
# extreme difficulty scaling production new technology well understood ’ 1000 10000 harder making prototypes machine makes machine vastly harder machine
# aacarmack ’ big
# aacarmack lot pointless zeroes fp32 neural nets chop 16 32 bits without losing meaningful precision works well neural nets regular computing expects extreme precision
# ’ lots green space around factory building continuous “ open ” areas inside covered ’ internal semi truck roads inside giant monolithic building
# prior track record exceptional achievement engineering required prior experience working brain human physiology required teach ’ known brain much tbh
# lot happened 13 years
# speedrunning factorio real life …
# yup
# 🖤 fallout radio 🖤
# doubles underground nuclear shelter 😀👍
# aacarmack bit obscure starhammer amp stainless steel rat
# feed first thought parrot
# remind guys
# story life
#
# exactly
# story civilization first book little dry second book life greece incredible
# ’ wearing f1 engine shirt right
# rykllan anyone tracking tonnage orbit year launch vehicles
# someone boat service south padre boca
# frames stitched single frame tricky cameras overlap different ways amp creating video segments labeling amp training everything labeling tools training inference rewritten
# much
# 🇩🇪 natürlich 🇩🇪
# 112
# munger right
#
# blackscholes formula kinda bs big difference finance approximation amp fundamental physics pure math
# filmreview
# touché
# yup
# 13
# guerre comme guerre
# starts tweeting
# aacarmack already bidirectional communication human amp via phones amp computers ’ lossy amp slow especially output
# 50 likely make
# chart understates lithiumion potential roughly 13
# model 3 rated reliable car
# starship sn6 flew asimilar hop sn5 much smoother amp faster operation
# 🇩🇪🖤giga berlin mannschaft🖤🇩🇪 vielen dank hervorragende arbeit giga berlin
# 🍓 picking goal result strawberry fields forever
# time outer 20 300 tons thrust amp inner 8 210 roughly 7500 tons total level 15 tw boostership
# outer ring booster engines 20 28 tvc actuators steering control comes center 8 tvc amp differential throttle outer engines measure high thrust variant raptor probably high tw engine ever
# videodrome
# lockyer lhc tbh
#
# lockyer physics law everything else recommendation
# alexander rise hellenism film studies
# learned physics prof penn head fermilab amp still old homework ☺️
# amp giga berlin ’ headed germany week conversations harvard epidemiology confirmed highspeed rna printer potential helpful vaccines amp cures many areas
# antibody halflife cov2 short study spacex working harvard epidemiology appears low 2 3 weeks nonetheless reinfection rates low amp symptoms minor perhaps due memory cells
# nsf yet
# enough people read much level detail ’ useful predicting future accurately predict issues encounter shortterm finegrained level
# ’ blanket pass maybe events
# nsf booster design shifted four legs wider stance avoid engine plume impingement vacuum rather six
# aacarmack later versions larger device would potential
# yup
# conceptual telepathy
# ahem … starting soon
# “ physics either impossible trivial impossible understand becomes trivial ” rutherford
# giant gap experimental medical device use patients extreme medical problems amp widespread consumer use way harder making small number prototypes
# neuralink product demo 3 hours webcast
# raptor reached 230 mtf half million pounds thrust peak pressure damage version engine probably sustain 210 tons 250 engine 6 9 months target booster 7500 tons 165 million pounds thrust
# need 2 engines
# boring co tunnel vegas months operational
# soon
# ’ quite accurate
# many days
# nothing 👀
# leave house hardly ever call parents
# big bang started smōl
# asimov 🔥🔥
# olde skoole analog synthesizer ancient britain
#
# exactly
# lengthy background neuralink
# live webcast working device friday 3pm pacific
# feed astronaughty
# sci mars easier moon propellant production could get going ship ship propellant plant needs make 2 tonsday
# sci starship propellant 78 oxygen o2 plant moon would enough otherwise could bruteforce tankers low earth orbit ’ probably faster
# sci ’ lot frozen co2 amp h2o mars heating planet densify atmosphere ’ solvable
# sci perhaps day ocean northern part mars
# ’ almost working reliably
# orbital launch mount
#
# 400 whkg high cycle life produced volume lab far probably 3 4 years
# starshipsuper heavy 10x mass zenit mostly launch ocean spaceports longterm
# starshipsuper heavy 10x bigger mass amp volume
# metaphor life
# uh oh
# kolz09 🤣
# hardcore techno vielleicht bisschen fahrstuhlmusik toilette
#
# direct democracy short comprehensible laws voted directly people snake jazz
# 🐍🎷
# ’ quite hard us write software needed cover basic car functionality maybe could something nature
# bureaucracy inherently kafkaesque
# dankeschön brandenburg amp grünheide
# 👆
# medical check aok
# might run president 2024
# long chain hydrocarbons amp lowering preburner combustion temperature make big difference
# absolutely needs liquid cooling ’ applying experience cooling half megawatt drive unit power electronics cars computers
# push ten flights starlink
# absolutely 😃 🏝
# stve scorcher
# elevator music underrated
# bass3d ’ counterintuitive raptor much thrust high isp liquid high density propellant amp pumpfed light tanks beats hot gas flip said hot gas beats heck n2 orbital manuevers amp stabilizing ship landing high winds
# payload reduction due reusability booster amp fairing lt40 f9 amp recovery amp refurb lt10 ’ roughly even 2 flights definitely ahead 3
# fairing chute control amp ship control closing loop locally operating spacex autopilot
# ms tree catches fairing net
# 😐
# somewhere cruising deep space
# must aliens
# max demonstrated raptor thrust 225 tons amp 90 tons ’ actually quite similar merlin amp raptor could throttle way lower added design complexity raptor preburner amp merlin gas generator flameout limit lower bound
# 💨
# ’ engine sn ’ building sn8 ship
# sn40 tested amp several upgrades 330 bar engine reference 330 bar raptor produces 225 tons half million pounds force
# bass3d impressive render note legs bigger amp ’ way stuff engine bay main engines actually majority work turning ship vertical landing
# sci might sting little …
# sci could long period comets intersect earth right ’ observed humanity ’ short recorded history comet sl 9 punched roughly earthsized hole jupiter
# cybertruck option package
# got
# “ tanks 4 memery ” panzer lake
# big milestones coming
# africa big
# real possibility
# ☺️
# 🤣🤣
# cover barbie girl
# sounds right
# elon crysis rocks
# feed metal fudgelike consistency near melting point smoosh together
# feed make falcon 9
#
# 🤣🤣 hasty govt 🤣🤣
# absolutely ’ seem govt move fast enough
# yup
# meant “ 4d ”
# fsd improvement quantum leap ’ fundamental architectural rewrite incremental tweak drive bleeding edge alpha build car personally almost zero interventions home amp work limited public release 6 10 weeks
# h2o ch4co2 n2 iron nickel chrome aluminum necessarily order matter far gold platinum space travel
# odds …
# bass3d sn8
# psyche
# starship fairing actually height shown dome flatter amp tip accessible usable volume 1000 cubic meters
# nobody would suggest buying airplanes fly amp crash ocean would absurd …
# hex tiles slightly different mounting method need bigger sections tiles see hold cryo shrinkage pressure expansion amp body bending
# sn7 new alloy test tank taken burst pressure sn8 body flaps amp nosecone
# sn 5 amp 6 starship production complex texas
# twin peaks
#
# 🤣🤣
# wonder reads twitter feed
# 🎯
# 💯
# max think get velociraptor tw merlin latter started half current tw
# seems increasingly likely
# sn5
# ’ several short hops smooth launch process go high altitude body flaps
# soon
# exactly
# mars looking real
# possible flight 3 mins
# likely
# highly likely road
# scrubbed day raptor turbopump spin start valve ’ open triggering automatic abort ’ figure amp retry tomorrow
# ’ boca control room hop attempt 33 minutes
# feed tbh must confess occasionally pontificating highconcept things
# space new air
# acquisition signal expected 5 mins
# dragon travel south new zealand florida 37 minutes
# coming hot
# astronauts land 2 hours
# however prove superdraco landing could work propulsive hover
# 🧙‍♂️
# bbc article provides sensible summary done
# ramses 😎
# aliens built pyramids obv
# ancient egypt incredible esthetic stands day
# ☺️
# feed engineering magic made real
# construimos
#
# 🖤🧛‍♀️total eclipse heart 🧛‍♀️🖤
# 😮
# skeptic ’ aware
# sometimes touch …
# 🤣🤣
# robot heart 🔥🔥
#
#
# 😉
# sum gt parts
# aw government money far talk trillions
#
# ryan ’ prototype color
# 🕊🕊
# fuel spin valve ’ open fix amp try tomorrow odd tvc hydraulic pump behavior
# kapital nutshell
# exactly
# 🤣🤣
# hold beer
# onion rose
# dropped
# 🌹
# ’ beat br
#
# planet claire 🔥🔥
# 🤣🤣
# 🤣🤣
# need high brinell hardness amp high corrosion resistance cybertruck ’ faceted nature formability important
# turning shade outdoor restaurant boca
# days 🤣🤣
# song whistle strangers night
# morenos exactly
# get lithium australia
# 🤣🤣
# reminder ’ favor universal basic income
# competition ensures companies work hard serve needs customers
# basically pixel size
# oven keeps asking wifi password ’ gon get
# ’ soul soul
# adding people next version
# 2 minutes later …
# another day 2020
# individualized mass transit future
# coming soon
# human overseen first fully selfdriving
# ’ say involves 🐻
# 10 🔥🔥
# 🤣
# stings
# memes send … memes …
# nothing gaslit people movie gaslight
# 👍
# myneni sound amp flame color quite different
# 🤣🤣
# baby löffel benutzen
# aacarmack ’ almost right
# aacarmack vr twitter avatars saying mentions 😈
# bring life mars
# fairing halves caught space ships
# doug still long way go reuse matters degree ’ rapid amp complete
# long since last
# launch 20 mins
# months production release already alpha build
# lithium extremely common earth found almost everywhere
# american born south africa left 17
# 🤣🤣
# potential
# station manufactured 5 mins lax
# contribute chromosome amp mitochondria constant except mutations
# 🤣🤣
# bde
# many
# ’ inevitable
# 💕💕
# 🤣🤣
# feed gigafactory product even car
# might indooroutdoor rave space roof
# giga berlin
# considering
# small note latch post near base gone amp powered ethernet wire less obtrusive production version
#
# thing call “ money ” slow lossy amp unsecure database labor allocation investing meaningless without people least agi happens obviate need labor amp necessitate ubi
# avoigt 🤔
# group mass orbit accurate metric launches although orbitadjusted gtogtleo would increase competitor mass numbers
# reusability essential rocket single use absurd single use airplane f9 engines already fire 3 times flight
# wild times
# maybe design flag mars
# feed 48 65 78 20 74 6f 20 74 65 78 74
#
# spqr
# actually payout vesting stock options may never pay stock ’ sold 5 years exercise stock must bought amp income taxes paid hold value 5 years
# symbiosis wait
# ’
# net get past mars asteroids moons jupiter amp saturn inevitably reach uranus
# 🖤✨carl sagan ✨🖤
# nailed
# 🤣🤣
# read story civilization amp ariel durant
# 69420
# may started already
# ’ absurdly large
# yup
# 🤣🤣
#
# 🤣🤣
# boyarbeatz
# 🤣🤣
# false landed montreal age 17 2000 backpack clothes amp suitcase books father bankrupt amp long time inherited literally nothing
# news sometimes created always curated latter pernicious given day thousands potential stories picking stories written amp prominently ’ placed handful publishers control much public narrative
# 😂😂
# false never introduced either anyone
# comesback sounds sketch
# haute couture
# exactly
# sec three letter acronym middle word elon ’
# busted secretly ♥️ short shorts
# wears short shorts 🤣🤣
# rasmussen rodco bs
# rasmussen rodco cherrypicked state fifty saw minor uptick show whole country
# yup
# rodco rasmussen ’
# ’ building anything ethereum ’ use
# seems fishy
# shareholder limited space sign fast final confirmation date amp location
# need finish building much longer vacuum tunnel speed tests amp probably additional competition tunneling
# questions answered battery day sept 15th webcast although much see person
# starlink provide global coverage
# papili fixing
# hart bill needs revoked gives absurd power county bureaucrats
# accurate would explain lot
# levitt right
#
# dogs rock
# verified far widespread simply someone claim
# ’ close though 😅
# controls memes controls universe
#
# menieb 🤣🤣
# literally
# coming soon
# north american supercharger usage tracking exceed pre covid highs 2 3 weeks lot noise signal
# think could make work
# exactly carbon tax needed correct unpriced externality amp market rest consequences slow action serious opinion need convert gt80 global road amp air fleet renewables 2050
# could slightly faster
# two starship tanks midbay
# canada major priority starlink
# september sounds right
# much disagree action experience skillsets net job creators visa reform makes sense broad
# changed 3k july 1st
# titans done 2k via inapp purchase
# patched
# entirely possible social media limbic amplifier inherently destabilizes civilization
# probably early q4
# 2019 seems quaint amp long ago
# purpose
# mars souldog
# titans follow tomorrow
# deus ex halflife 2 bioshock mass effect 2 fallout 3 amp new vegas saints row iv
# titans sound excessive look
# feels long ago
# add pto day annual review next quarter
# confirmed
# schnitt
# comes standard cybertruck
# real
# parrish maybe incat
# many test flights commercial passengers carried first earth earth test flights might 2 3 years
# parrish need far enough away bother heavily populated areas launch amp landing subtle could get within miles spaceport boat
# directionally correct zenit order magnitude smaller starship system amp ’ back amp land
# spacex building floating superheavyclass spaceports mars moon amp hypersonic travel around earth
# maybe flextape
# publishing aliens
# coming soon
# model cars made since late jan 402 mile range making official
# absolutely
# china amp asia pacific supercharger usage precovid highs north america catching fast europe slightly behind
# looking likely
# maelstrom jbeck throttling done adjusting flow ox fuel preburners lower limit thrust ox amp fuel turbopump injector preburner “ stiffness ” essentially preburner elements start flaming
# jbeck yeah merlin using single pintle injector cold liquid propellant needs longer chamber raptor uses large number coaxial injectors despite merlin less half thrust propellant enters raptor chamber hot gas ’ already mixed
# dyce farenough np2013 accurate
# get even simpler two instructions starlink plug amp point sky done either order
# feed foretold
# feed stonks
# gvf exactly chartering dedicated 747 flight around world costs less buying small single engine turboprop plane way giant reusable rocket flight way cheaper tiny expendable rocket used
# thought onion article
# got fuel cell question 8000 times
# ’ getting biblical
# trèy boucher
# actually ’ sn30 raptor
# crew doug ❤️ laser beam long exposure shots
# recycled
# electric cars produce much less co2 fossil fuel cars taking electricity emission amp vehicle production acount
#
# combined spacex deep subcooling propellants near liquefaction temp n2 use common dome ch4 amp o2 liquid similar temps amp higher tw engines enables facto higher deltav h2o2 stage
# wort reading whole thing
# 🎶to meme impossible meme 🎶
# ’ working new legs wider stance amp able autolevel important leaning wind landing rocky amp pitted surfaces
# forward thrusters stabilize ship landing high winds goal max payload moon ship heatshield flaps big gas thruster packs needed need bring early ships back serve part moon base alpha
# absolutely
# 🤣
# stankonia
# 81m
# pursuing three hard say right
# gateway mars
# lot happened since
# 3600 tons propellant almost 80 densified liquid oxygen
# spacex software
# giant high bay coming soon
# starship production complex boca chica texas
# big line barbershop
# thursday
# gerontocracy touch people
# probably get trouble feel say
# methalox right propellant staged combustion amp highly reusable
# dozen transfer windows 25 years
# twitter
# starship key making life multiplanetary amp protecting light consciousness
# banana feed ’ banana
# nine years later
# must due relativistic aging 😉
# brought home person placed almost decade ago
# спасибо сэр хаха рассчитываем взаимовыгодное процветающее долгосрочное сотрудничество elon
# dragon docks station 3 hours
# doug station dragonship endeavor
# 5 mins t0
# slowed bit allow supercharger v3 production get going speed
# superchargers coming soon
#
# sunset
# joy feels long ago
# 😎
# dragon dawn
# 🤣🤣
#
# fallout new omaha
# 🚀♥️
# ideas sound sensible spacex ’ “ brain coach ” think maybe gave talk
# mars needs happen soon
# made earth humans
#
# reviewed design franz last night even 3 smaller small pretty much size ’ probably smaller tight world truck point
# 🤣🤣
# astronauts orbit 5 days
# medium message
# time return
# new new hampshire license plate
# open eyes look skies
# рак горе свистнет
# очень нравится звучание русского языка
# jay really knows cars nextlevel
# 🤣
# mission control cape
# doug astronauts orbit next week
# … openly moderate
# 💕
# exactly
# stanley 🤣🤣
# dayquil amp nyquil time
# red pill 🌹
# rowling still 025 bitcoins btw
# frankly ’ even know “ plethora ” means
# weeks away
# still
# geeman famous last words
# said run office president sigh even owns newsweek days lost track
# ’ going push date attendance low maybe two parts webcast next month amp inperson event months later
# probably sooner
# happening lot
# exactly
# statistics stopped valid anyone “ covid symptoms ” almost anything counted covid
# exactly
# exactly
# exactly
# said another way falcon heavy 23 thrust saturn starshipsuper heavy double thrust saturn
#
# life lived
# ice cream sundae martini glass
# tolkien rocks
# personally think
# always disagree closed mind … nature ’ sink sigh
# appears saying untrue
# boutall feed 🤣💕
# lil baby
# 🤣🤣
# exactly
# exactly
# zork dungeon master
# babies rock 💕
#
# sci real
# message received
# sheriff bianco rocks
# georgia lifted lockdown 15 days ago
# right
# pattern atoms
# ❤️ mom
# meant say скучный идиот
# идиот
# feed bnut 🤣
# half 🐝 philosophically must ipso facto half 🐝
# boutall feed turns hobbits enormous
#
# ’ mostly ship except thrust bulkhead 31 engines vs 6
# yes mostly use ship every week going moon instead every two years mars best case
# would 10 times cost payload surface mars
# 🤣🤣
# franz absurdly similar tastes 🤣🤣
# peak rate half version 1 right heavily dependent users cell aiming latency 20 ms
# fully amp rapidly reusable orbital rocket fundamental extending life beyond earth propellant cost roughly 1000th vehicle cost unless using foolish propellant principle cars planes boats etc
# case chilling gas back liquid
# flare stack flamed weeks ’ recondensing methane using solar power flare stack
# spacex
# archangel12
# nafnlaus dke nutshell ’ almost always dumber think
# levitt rocks
# ferguson tool
# boy
# x æ a12 musk
# neilson hours away
# anyway ’ talking 2 much confident model get 400 miles soon retest allowed
# seems unlikely right
# mostly accurate liquid ch4 temp got high time offloading propellant retry later today
# sn4 🔥 soon raptor looks smōl
# many silver linings amp
# 🥜
#
# exactly
# running lame collection bots amp trolls anyway try harder ’ engineer knucklehead “ business ” side
# online
# 🤣🤣
# much
# exactly
# much anime bitcoin
# 🔥
# 🤣🤣
# reality parrot parody
# bring
# 👆
# baby due monday
# oh say starspangled banner yet wave
# gave proof night flag still
# rockets red glare bombs bursting air
# real
# got
# exactly
# savage tweet nafnlaus ’ say …
# sound reasoning
# yup
# sweden sensible
# exactly
# california hhs server crashed maybe covid
# actual data reference chhs
# bravo
# sensible
# bon voyage
# bravo texas
#
# 💯
# much arbiter world
# silicon valley become sanctimonious valley
# starship able launch telescopes 3x diameter hubble
# soon tiktok
# oddly mesmerizing
# sn5 get three
# 49 bar kind softball tbh ’ enough fly
# sn4 passed cryo proof 😅
# make ft claims
# ft saying current death rate extremely unusual ’ saying 2017 higher correct
# snowing texas
# cryo test underway
# considered probable ’ covid test cough high temperature enough
# dark
# may 🥜 tweets 🔥🔥
# yet
# ’ little dicey tbh thrust dome redesigned current four separate layers steel places
# 150m
# dogecoin mode
# irugu 👍 🤣
# basically describes soc 0 vs soc 1 fsd computer right soon change
# ’ strictly coupled ship serial number might sn5 might used manufacturing pathfinder
# csquared usual things building production system raptor gt1000 harder designing
# ’ spitfire engine amp wizard
# needs halfway east coast
# saying new giga texas cybertruck produced wherever fremont max capacity
# mythic quest 🤣🤣 mttd
# merlin simple compared raptor
# ’ hardcore
# exactly
# youhadonejob1 🤣🤣
# starship sn4 tank test stand
# maybe cybertruck …
# shall
# private beta begins 3 months public beta 6 months starting high latitudes
# 420 operational starlink satellites 🛰 😉
# style new york seeing results invasive ventilators wuhan
# frankly much stimulus money questionable much oil amp gas seems especially
# style numbers told wuhan 80 90 mortality rate invasive ventilators good odds
# 🤣🤣
# red sky mars blue dawn amp dusk
# murphy check warranty …
# detroit
# another reason reported mortality rate overstated dying covid dying covid media keeps reporting former latter
# maybe 15 change interior dimensions still roomy
# probably 3 6 months
# moreover mounting evidence invasive suboptimal covid put boris johnson mask ventilator invasive tells something article incorrectly conflates invasive “ ventilator ” makes many good points
# 🤣🤣
# header tanks quite small relative main 30 tons vs 1200 tons uses tip nose
# sn5
# 🤣🤣
# orbital human spaceflight returns cape six weeks
# cancelnewsnetwork
# trying fewer parts strakes unlikely counterintuitive cfd results hypersonic amp subsonic regimes starship controlled falling flying
# flaps actuator amp static aero undergoing redesign mass reduction amp simplicity
# exactly
# 🤣
# 🤣🤣
# karma real
# based direct requests icu wards exact specifications unit provided shipment
# perhaps unaware twitter search function hospitals acknowledged receipt ventilators
#
#
#
#
#
#
#
# exactly
# “ ’ jump intubation ” — dr caputo
# wachter sounds right
# wachter roughly survival rate intubated patients ’ hearing 10 20 overly pessimistic
# wachter know two nurses job offers revoked nyc arlington
# wachter currently
# wachter hearing almost hospital icus excess capacity cases 60 empty
# psyd jbeck sn4 ’ get flaps flights engine reset week flap actuator amp static aero design either sn5 sn6 get flaps
# psyd small launcher activity cool especially downsides helicopter retrieval ’ scale bigger rockets amp highly weatherdependent propulsive landing needed moonmars said ’ probably right move small leo vehicle
# psyd sn26
# psyd merlin arguably version 6 7 ’ real workhorse looks simple next raptor
# fundamentally atlas still dependent russia launch
# sorry meant say us rocket atlas close yet 100
# last checked million dollars less moreover f9 launching far often amp rocket fully nasaapproved launching astronauts gap increasing
# costs less insure falcon 9 mission ’ acid test
# initial production giga berlin model
# able wrap color pattern
# obrien 五輪書
# dayquil nyquil
# correct
# future strange expendable rockets would expendable airplanes today reusable
# lot happened 8 years
# 🤣🤣
# actually
# woodward … bs
# woodward string theory
# essentially
# mujawar
# simple arena often profound another
# aim zero velocity surface amp fall ’ fall fast
# 20th amp final dragon 1 mission complete
# high puckerfactor landing
# go
#
# starship fuel header tank
# music limbic resonator
# mdevries 🤣🤣
# ’ neither
# havanese amp came pound
# raptors
# press key continue
#
# see data review says morning may test configuration mistake
# mass initial sn ships little high amp isp little low time 150t leo fully reusable
# day
# scurve appears entering logarithmic phase
#
#
#
# launch stand
# hello inside
# logarithm graphs coming soon
# magnetic personality
# fast antibody test
# buzzfeed mind virus
# give away ventilators whether buy build
# dragonfire
#
# physics law everything else recommendation
# sn3
# meme proves
# ’ ducked
# feed 🤣🤣
#
# exactly
# according italian govt 12 deaths actually due c19 significant policy difference italy vs countries
# seen data hcq amp zpak hard find
# n95 masks amp getting paprs team reach
#
# based current trends probably close zero new cases us april
#
# monitor graph bottom cdc website new “ confirmed ” cases oftreported “ presumptive positive ” trending level next weeks amp negligible april pattern china
# 🤣🤣
# compare favipiravir
# last launch aborted due slightly high power possibly obviously related today vehicle seen lot wear today ’ big surprise life leader rockets used internal missions ’ risk nonspacex satellites
# 🤣🤣
# polygon ’ rhyme
# awe tow co wrecked
# wild times …
# potoski np2013 exactly
# seems happening lot
# np2013 sensible knows handle exponential functions reality
# whether zpak works situation ’ kickass many maladies
# sounds sensible
# ’ worse even told stanford check parasite amp still ’ find
# first misdiagnosed stanford hospital viral meningitis misdiagnosed sequoia visiting doc san jose general saw charts amp sent icu immediately 36 hours unrecoverable expert advice grain salt …
# given lot doxycycline
# feed 👍
# parts use 304l higher toughness cryo temps move internally developed alloys probably year
# probably raptor sounds different merlin
# lot raptors coming operating horizontal amp vertical firing stands mcgregor
# production exceeded preorders
# coming soon
# totally frank image search phone amp posted without looking closely
# ’ goal 😀
# wacktivism
# moon
# people spoken
#
# former
# model production east coast
# scouting locations cybertruck gigafactory central usa
# epic sound system amp woofers size car
# ✌️
# rammstein
# lucent dossier 2011 amp think saw 2012 ’ realize later
# busted 🤣🤣
# 🤔
# market bit high anyway due correction
# sn2 thrust puck passed cryo pressure amp engine thrust load tests late last night
#
# studied blade
# fatality rate greatly overstated test kits respiratory symptoms tested c19 minor symptoms usually prevalence coronaviruses amp colds general population high
# virality c19 overstated due conflating diagnosis date contraction date amp overextrapolating exponential growth never happens reality keep extrapolating amp virus exceed mass known universe
# accurate
# envelope expanded
# rocket land highest winds ever cape canaveral tonight intentional envelope expansion
# final dragon version 1 mission tonight
# tech new catalog engineering ’ possible catalog first principles
# 💕
# bernie ’ tax rate 02 high
# sleeving sn2 dome high bay
# dogs rock
# ✌️ bro
#
# ’ puck base takes engine thrust load ’ shuck puck
# ’ flextape need
# … night
# need finish work autopilot core foundation code amp 3d labelling functionality happen quickly long
# 👀
# skyart sent note twitter clarify posting spacex videos fine us paid rights bowie song falcon heavy launch
# testing raptor vertical configuration giant tripod allow us simplify aspects engine design
# ’
# full disclosure ’ actually 3000 year old vampire ’ trial assuming false identities centuries
# 3 sn2
# ’ cones invented
# tinny
# woody
# obv
# wall austin
# model 3 achieves 350 mile actual range vs 310 epa sticker consumer reports testing
# science gone far
# 🔭
# ’ mostly balance ship entry delivering satellites front light amp back heavy due engines amp landing legs
# sorry meant say lox header tank tip nose ch4 main tank lox main
# lox
# hardest problem far building production system something big 2nd hardest achieving full amp rapid reuse payload orbit 2
# ev probably
# ev attach wheels landing legs amp tow starship launch pad
# rate two bugblatter beasts traal
# high bay stacking starship engine bay propellant tanks amp fairing fka nosecone sections almost done
# header tanks 2 main tank volume big deal pressurized volume still 1000 cubic meters
# o2 header tank tip nosecone ch4 header main ch4 tank
# order written
# persuader hammer fix sn1
# rocket nosecone production texas
#
# 🔥🔥 makeup
# conversations gates underwhelming tbh
# karenhao
# karenhao openai open imo
# looking forward international expansion later year 😀
# direct links ’ needed offer service starlink initially bounce signals groundocean relays get 🛰 🛰
# sorry probably going lot rocket pics 🤣🤣
# ryan depends car built many small hardware improvements somewhere 373 amp 390
# ryan regulations require calling something else added
# ryan ’ tough performance vs range tradeoff plaid absurd performance holding range roughly constant
# frame rate δt≥ℏ2δe
# resolution reality
# reminded lady shalott waterhouse
# unnerving
# zubrin might used around flap joints
# zubrin shielding needed orbital speeds
# zubrin unfortunately starship unlikely survive leo entry intact without shielding windward side none required leeward even windward shielding light
# hedgehog 😉
# whoop whoop
# æsthetics
# integrated roof amp solar light enough almost home
# mantis sounds note gets less shiny automatically due dust amp weathering brand new
# midsection starship propellant tanks
# foundation asimov
# mars earth terminus trantor
# order
# first two domes frame sn2 third sn1 thrust dome
# back boca
# mom wrote book ♥️
# 🤣🤣
# upon time hydrogen vacuum
# 🔥🔥cropping
# saw lot launching kwajalein early days spacex
# anything ’ result smudgy image lens cover glass get two part hydrophobic coating probably better use first part
# begins …
# “ nutcracker ” tho
# 🤣🤣
# 💕
# programmed pick many strawberries possible cultivated nothing strawberries earth ’ land would strawberry fields forever
# new fins
# rococo basilisk
# realiti made wait
#
# things moderation especially etymology
# essentially quotes ascribed churchill
# guess ’ lefthanded
# 🤣
# tiny robots lasers
# 🤣🤣
# 8th hottest song soundcloud
# starship concerto zero g
# giga texas
# uh oh
# tried hydrophobic spray
# starship career day stargate building boca chica blvd tx thursday 3pm 9pm
# 🔥🔥🔥
# wait see next version vs presented last year ’ awesome
# probably summer
# pytorch frequently used external tool setlibrary
# nn initially python rapid iteration converted ccraw metal driver code speed important tons cc engineers needed vehicle control amp entire rest car educational background irrelevant must pass hardcore coding test
# profound impact high bandwidth high precision neural interfaces underappreciated neuralink may human soon year needs unequivocally better utah array already humans amp severe drawbacks
# 66 years first controlled powered flight landing moon half century later still unable return must change
# trollsbots need deemphasized relative probable real people ’ paid push agenda scam google still shows bsscam pages ’ several clicks away
# feed make buildings highstrength steel concrete needs steel anyway
#
# meant say forms “ cold ” influenza
# become tiesto night
# 🤣🤣
# vibbbe
# wrote lyrics amp performed vocals
# … cause … ’ …
#
# крипто
# releasing soon emo g records
# exactly mars propellant production combine atmospheric co2 amp water ice make ch4 methane amp o2 earth longterm shortterm falcon flight uses roughly fuel mass 747 flight falcon 71 oxygen amp starship 78 mostly fuel
# r smôl
# ice
# 85 bar
# chairs underappreciated
# stars starship ’ mirrored hull reflected
#
# gardi already done
# first two domes sn1 almost complete
# starship 9m test tank made 75 bar room temp small leak weld doubler repaired amp retested cryo
# ’ working
# facts niche
# meme necromancy
#
# base moon city mars
# ’ working
# working
# ’ list
# 🤣
#
# one1 michael marks ’ ev drori helped coceo ’ much automotive domain expertise
# gardi bergeron exactly
# dragon high altitude supersonic abort test risky mission ’ pushing envelope many ways
# 5 mins liftoff
#
# meteor
# dragon spacecraft supersonic abort test coming either tomorrow sunday depending weather
# marchante change
# hehehe
# loading mars fleet earth orbit 1000 ships depart 30 days every 26 months battlestar galactica …
# needs anyone go loans available ’ money
# ’ goal
# building 100 starshipsyear gets 1000 10 years 100 megatonsyear maybe around 100k people earthmars orbital sync
# starship design goal 3 flightsday avg rate 1000 flightsyear gt100 tonsflight every 10 ships yield 1 megaton year orbit
# megatons year orbit needed life become multiplanetary
# bigmike ’ right
# reaction cyberpunk 2077 slipping release date september
# ’ amazing nonlinear effect gravity starship travel surface mars surface earth requires massive booster earth orbital refilling get mars 38 earth gravity
# densification ’ needed return ship amp limited cargo mars ’ option increasing cargo return capability needed
# starship orbital vehicle sn1 liquid oxygen header tank amp nosecone
# debh advancing humanity ’ understanding universe fundamental motivator spacex starship put giant 🔭 orbit amp moon occluder could image 🌏 star systems
# skeptic person ’ mri machine another ’ railgun made primitive studying physics penn hard wield though
# tshirt bulletproof amp makes buff
# station
#
# bagwan need emojis
# course car able 💨 general direction
# able post video raptor tripod soon
# soon
# given tank pressure needed feed engine turbopumps amp pressurestabilizerelieve compression load cylinder walls
# 🔥 amp ⚡️
# 🎶 toss coin ur witcher 🎶
# phony
# sci sun green peak photon frequency
# 😉
# x
# put art fart
# king goblins master labyrinth
# ’ crosschecked rcs pulses mli dimpling video ’ likely cause
# since ’ main engine gives pitch yaw control roll control provided nitrogen attitude control thrusters
# tryin grow follower count pornhub …
# 🔥🔥🤣🤣
# dkedke
# least 4
# cgi irl
# bossart boss art
# 🤣🤣
# nirvana baby year away turning 30
# wikigenius
# zip2
# carlos gone
# feed ’ bit slow
# explains 🐈 🎥
# tbh
# gardi many ways solve problem power requirements much higher aircraft control surfaces moving giant body flaps rapidly achieving high power much harder high torque
# exactly
# talk q4 call
# barrel dome
# sounds right 🤣🤣
# seems long ago
# moving enclosed fairly clean room environment sn2 jan although unlike aluminum stainless steel welding super sensitive main issue boca get windy affects weld arc amp steel melt pool
# autogenous start tapping hot ch4 amp o2 raptor
# almost everything different parts stamped vs manually bumpformed amp tip tig welded vs flux core higher precision stronger joints amp 20 mass reduction
# use process raptor nozzle jacket knuckles dome stamped michigan 4000 car body press costs much less outcome
# muffin notmuffin
# new technology development schedules tend exhibit version zeno ’ paradox — given point ’ halfway
# 8 years later simulation mostly real
# 🤣🤣
# games 😎
# 😮
# absolutely multilevel tunnels go buildings mountains rivers anything else amp directly connect destinations like aircraft sky need
# ❤️ sis
# literally 40th amp baltimore philadelphia gentrification
# wakefield cyber mikemo ramones amp bach
# wakefield cyber mikemo hope someone pics mom came visit weekend amp quite surprised helped work coat check amp guarded cash kitchen knife 🤣🤣
# 🖤
# exactly
# cyber mikemo person blocked ’ read tweet whats deal
# cyber mikemo started zip2 2k plus overclocked homebuilt pc 5k bro amp 8k greg kouri good guy — greatly missed dad provided 10 200k angel funding round much later risk reduced amp round would ’ happened anyway
# cyber mikemo ’ emerald amp worked way college ending 100k student debt ’ even afford 2nd pc zip2 programmed night amp website worked day bs coming
# federal
# probably 2021 depends regulatory approvals
# night spacex team working starship tank dome production difficult part primary structure dawn arrives …
# future feature
# turn auto navigate feature amp car activate trafficbased navigation work home calendar depending context soon input required
# possible step time anything release fleet big implications days example someone ’ data roaming amp video enabled get giant cell phone bill operating 40 countries results many corner cases
# ’ building superchargers fast possible need ramp v3 supercharger production
# people still ’ know ’
# odd try pressing scroll wheel buttons reboot forwarded service
# black mirror
# parasite
# stock art
# 🤣🤣
# ’ wan brag … 🚘💨
# henry cavill 1
# wiki zone zillion edits least ’ obviously curated day probably write fictionalized version reality 🤣🤣
# another milestone
# “ inhouse ” 🤣🤣
# feed ’ years
# starfleet begins
# sure🤞
# ’ hear much element 43
# cinnamon toast crunch
# lämpe
# telemetry indicates soft touchdown water fairing might still reusable
#
#
# view fossil fuel cars
# crossing scurves standard tech transitions
# baby yoda 💕
# literally brain vat vat skull everything think real electrical signal feels real though
# games render look look compute load would otherwise impossibly high observed objects probability function aka quantum mechanics
# smol ∩ puppy ∩ math
# plausible
# meant say “ render speed ” frame rate locked
# dlc
# way many paywalls amp spawn points
# read instructions
#
# mkavin ’
# really
# maybe starship ’ def got payload capacity …
# ’ def wrong solar power gigawatt square km need 100 100 mile patch deserted corner arizona texas utah anywhere power entire usa analysis goes calcs
# launching third flight dragon spacecraft station tomorrow
# hydrogen became sentient
# 🔥🔥
# people often think ’ breathing oxygen actually breathing nitrogen 78 side serving oxygen 21 argon sauce 1 spiced co2 h2o amp dash neon amp krypton etc
# hydrogen light odorless gas given enough time turns people make statement
# ’ artificial
# ’ generational thing
# def dainty
# 250k
# bring
# 200k
# yup sledgehammer impact cracked base glass steel ball ’ bounce done steel ball window sledgehammer next time …
# cybertruck pulls f150 uphill
# cybertruck last product unveil mostly unexpected technology announcements next year
# good question ’ new variant 300 series stainless steel gets coldworked many times depending kilotonnage press
# stevee wrapped color
# padival long term probably makes sense build smaller cybertruck
# 🤣🤣
# hardcore body engineers understand profound level
# ⚔️ study blade ⚔️
# even bending requires deep score inside bend prototype made
# reason cybertruck planar ’ stamp ultrahard 30x steel breaks stamping press
# 187k
# 146k cybertruck orders far 42 choosing dual 41 amp 17 single motor
# 🤣🤣
# armored personnel carrier apc
# riding cybertruck
# 🖤🖤🖤 syd mead 🖤🖤🖤
# threw steel ball window several times right event amp ’ even scratch glass
# option add solar power generates 15 miles day possibly would love selfpowered adding fold solar wings would generate 30 40 miles day avg miles day us 30
# see 2077 😉
# nobody expects cybertruck
# yup
# course
# long journey
# tonight
# maybe ’ need key
# gravitas overrated
#
# cybertruck unveil thursday night
# meaning fair boeing gets much thing
# ’ seem right
# semiinfinite
# seems likely 🧝‍♂️🧝‍♂️ hipsters
# right trajectory neurosilicon symbiosis ’ appear intersect trajectory agi goal neuralink raise probability 00
# gentrify mordor
# build batteries powertrains amp vehicles starting model
# 🖤♥️💛 giga berlin 💛♥️🖤
# starlink vertical pad
# exactly
# without fully amp rapidly reusable orbital rocket humanity never multiplanet species
# 😘
# 141 mpge
# deleting throttle allows engine achieve max thrust max thrust variant variants throttle
# current global payload orbit capacity 500 tons year falcon half
# build many starships falcons 100 vehicles amp 100 tons orbit ’ capacity 10 million tons payload orbit year
# payload orbit year starship fleet mindblowing metric ’ designed fly 3x day 1000x year
# gasdiesel cars
# course
# cybertruck unveil nov 21 near spacex rocket factory
#
# cooney said starship spaceports probably need 20 miles 30km offshore acceptable noise levels especially frequent daily flights would occur point point flights earth
# fires real
# ♥️ snacks ♥️
# soon spacex launch astronauts station
# treebeard
# ’ make much money product 1000 actually means lot
# apologies waiting solarpowerwall outside california prioritizing affected wildfires
# extremely high
#
# sandwich time travel explanation
# physics facts
# srsly
# transparent aluminum real thing
# boeree strange think civilization 5000 years old dated earliest writing less lifespan fruit fly compared age earth
# california time
# open call qampa
# v1 switch v3
# actually …
# whoa worked
# sending tweet space via starlink satellite 🛰
# homes solar sell 41 according zillow
# carrot less stick
# pgampe says rolling blackouts expected california next 10 years
# time
# common myth incorrect
# begins robocalypse …
# lead character named woody
# yeah gimbal sl engines throttle control impulse goes vac engines
# oolsen station looking forward kerbal 2
# ’ keeping area ratio low enough fire raptor vac level without flow separation ’ leaving lot table
# max thrust version raptor achieve true tw gt 170 target 15 engine gt260 tf max isp version achieve 380 sec tw probably lt120 due big nozzle guesses
# umper station precise r distance center masses two objects center mass earth 6400km gravity change small space station altitude 6800km center earth
# station exactly moon since atmosphere
# station people ’ aware orbit “ zero ” gravity horizontal speed altitude spacecraft needs travel 25 times speed sound stay space
# rumors false
# ms chief amp ms tree
# first rewatch godfather part space jam
# underappreciated 🎥 watch
# really7 goes
# solar
# allows homeowner potential go completely grid
# car fsd without supervision ie robotaxi ’ able earn far monthly leaseloan cost allowing others use managing small fleet robotaxis career many amp much better driving single car
# 😉
# boutall ♥️ asterix amp obelix
#
# working
# call “ caraoke ” ’ 🚘
# shortfall gravitas
# arthur garythebot next update
# garythebot siq burn gary siq burn
# boutall hinge
# color orange named fruit
# hardware cape need static fire reconfigure flight launch probably late nov early dec
# ’ worth spacex schedule ’ reviewed depth shows falcon amp dragon cape amp testing done 10 weeks
# gayer 🤣
# culture class really something
# hāhā
# done
# ’ tip iceberg
# 💨 amp 🐐 sounds course
# consider
# understand next question
# understand nature consciousness
# exactly
# let ’ go boyz
# welded steel
# rosetta vangelis incredible
# enhanced get
# aiming weekend
# yet
# first point release update expected go weekend
# 20km works orbit
# ’ right except sensors sensor partially ablate hot amp replaced
# ’ “ secondary ” structure concerns engines amp primary airframe
# raptor cost tracking well 1m v10 goal lt250k v20 250 thrustoptimized engine ie lt1000ton
# inside starship cargo bay header tanks mounted tip nosecone offset engine weight rear
# 😀
# make life know multiplanetary
# starship halves joined
# space ’ much power going engine ’ close limit known physics materials many places
# space ’ focusing production sn12 need 250 bar even bit less starshipsuper heavy anything 250 nice amp ’ get around needed flight
# space probably around 6 7pm
# figure speech
# meanwhile back reality
# media report false
# space raptor uses milled copper channels inconel jacket way
# three raptors starship
# always
# gary rock
# anonymous bot swarms deserve closer examination ’ evolving rapidly something ’
# advanced beyond basic bots ’ applied manipulate social media ’ long
# wests exactly
# 50m
# mk1 ship around 200 tons dry amp 1400 tons wet aiming 120 mk4 mk5 total stack mass max payload 5000 tons
# six two windward fin amp two leeward provides redundancy landing unimproved surfaces
# transporter
#
# правда
# язык подвешен
# exactly
# exactly reusable heatshield minimize peak heating ablativeexpendable minimize total heat therefore reusable like starship wants lift high mach reentry lower peak higher total heat
# sent note check
# classified uro unidentified road object area 69
# bottom half starship night top half forward fins amp header tanks probably stacks wednesday three raptors already installed
# raceway amp flap hinge aero covers
# leaving spacex starship build site boca
# 😉
# approximately correct fire acs thrusters rotate vehicle amp ignite raptors full gimbal angle complete turn
# aero control comes crosssectional area moving vs flexible whether front rear long within bounds center mass amp pressure
# current analysis ’ fully bought suggests 2 rear fins separate airframemounted legs lighter plan mk1mk2
# stability controlled rapid movement rear amp fwd fins entry amp landing well acs thrusters smaller leeward “ fin ” would simply used leg
# stability issue 3
# nose tip forward movable fins cold gas attitude control thrusters header tanks landing composite pressure vessels several large batteries etc placed balance high mass raptors amp rear fins bottom
# adding rear moving fins starship mk1 boca chica texas
# srsly
# course ’ obv
# e👁🥧 1 0
# “ smart ” summon work v20 hardware wide release
# lambroisie place vosges
# amazingly onion article
# jameshatfield
# regrette etienne
# news …
# busted
# apollo
# landing leg frame
# area 51 area 51
# droid junkyard tatooine
# absolutely
# enchev 101
# 🚀♥️ starship team ♥️🚀
# fundamental operating principle prices may change change equally amp never function bargaining normal products weirdly auto industry parts world
# used butt bellows blowing smoke … along thames river london
# ...
# bought wood built little treehouse boys beautiful ways spend afternoon
# kids days grown secondgraders wow audience school production equus
# model performance powertrain produced much torque today broke dyno 44 sec 060 mph problem
# finished massies book catherine amazingly expansive compelling portrait incredible woman highly recommend
# respectfully disagree larry made awesome moves last year laid foundation g kick butt 2012 hes stud
# everyone really thinks “ mayans good predicting future thered mayans ”
# careful find knife libertys neck fate great sense irony
# however chinas real estate crisis explode way makes look puny cant hide much longer
# yeah 2012 great american economy jobs weve mostly dealt overbuilt housing crisis
# first prediction 2012 true ouch head hurts
# really matters current rocket tech including sucks becomes fully reusable suck
# clear ctg absolutely bang horse close friends liked showers together spoon night
# right mood scented candles barry white singing cant get enough love baby magic mean horsefing happens
# saying shouldnt pass judgment based night passion sometimes things happen go moment
# reading robert massies book catherine great yeah know youre probably thinking really f horse
# saying necessarily good bad reality force us live consequences actions
# interesting economist article humanitys collective actions created fundamentally new geological age anthropocene
# liked screw business usual lot approach taken heart really smart move
# ever wanted know real truth moon landings best onion article ever
# walked around neighborhood recently rebuilt help apj others
# returned trip haiti covered lot ground saw many tough situations need lot help
# kanye stopped spacex rocket factory today
# raul campos invited guest dj gig kcrw hear random holiday season music selections
# yeah really mom attest sure handle 140 char missives put longer thoughts g
# singing acting talent sorely missed south park sequel coming soon
# sam harris wrote nice piece awesomeness hitchens may good rip
#
#
#
#
# Clust  5
# bickett yes
# feed haha
# yes
# great shot
# wow mayo sure salty
# ok
# yes helpful thanks beta testers
# congratulations spacex team
# sure
# raj haha
# 96 yes
# creative
# yes
# congratulations
# making progress
# sweet …
# nice
# … yes
# yeah
# wow
# definitely
# interesting
# yes play sexy snake jazz 🤣
# yes
# haha
# yes
# true
# aacarmack completely agree
# sure
# true
# haha
# true
# haha true
# enough yes
# haha
# yes
# haha
# thanks
# yes
# yes
# good movie
# great idea
# sure
# embrace tunnels
# true
# yes good insight
# yes
# true
# haha
# yes
# great trip germany support government amp people super appreciated
# trust ur butt haha
# cool
# good summary
# sure
# yes
# yes
# sci pretty much
# wow
# ’ great
# bold move sir bold move
# truly useful exaflop facto fp32
# yes
# ok
# great mission patch design
# truth haha true
# impressive
# aiming make super fun
# clearly
# true fact
# feed pretty much
# true
# cool
# lsp congrats great launch
# sure
# sure could use good rave ’ favorite techno
# sounds great
# nafnlaus haha
# like great sense humor
# haha
# amazing
# great song
# cool
# great song
# haha thanks kara
# pretty much
# haha
# agreed
# future good article
# good point
# great shot
# howard8 yes
# yes
# thanks
# yes
# ok
# cute
# welcome anytime
# thanks
# haha
# true haha
# true
# yes
# sure
# thank goodness modern medicine
# sure
# true haha rock
# good summary
# sure
# nice haha
# true
# wow
# true
# congrats tesla team — rok
# thanks
# ok fine 🤣🤣
# aacarmack yes
# thanks tesla owners amp investors love work super hard earn trust amp support
# bad
# great interview 🤣🤣
# yes
# awesome
# haha awesome 🤣🤣
# likely true
# yes
# party …
# true
# sure
# jay awesome
# glad like
# henning great idea
# true
# glad ’ ok
# ok
# congratulations
# yes
# yes
# yes
# luck best superpower
# jb123 yes
# jb123 best definition innovation ’ ever heard
# haha sure
# nice
# parrish pretty much
# illuminaughty haha
# cool
# yes
# congratulations kathy
# lol
# feed wow
# wow extremely important
# haha true
# yeah super heavy stacking
# cute amp happy
# good point haha
# yes
# great
# human kind
# sure hope
# spacenews cool
# great episode
# sure
# cool group
# true
# fun less shun
# yes
# foust pretty good
# pretty much
# true
# true
# great wiki piece
# yes improvement exponential
# yes
# super exciting day coming
# yes
# thank
# great
# wow great writing
# much appreciated
# interesting
# good summary
# yes
# amazing
# pretty much
# ’ true
# ellis yes
# sure
# yeah
# yes
# r powerful 🧚‍♀️👸
# sr71 yes
# thanks maria 💕
# neilson happy healthy amp cute button
# yeah definitely future feature
# thanks
# well said lord sumption well said
# minecraft amazing legs
# pretty much
# sure thanks
# pretty much
# freedom
# still free still brave hell yeah
# haha
# incentives matter
# starship making good progress
# yes
# yes
# true
# free america
# interesting
# true
# interesting …
# great
# progress good
# definitely
# yes
# yes
# agree
# ’ great
# good
# yes
# haha sure
# good summary
# yes
# bergeron sure hope
# nice
# boca working rocket awesome team pretty great
# true
# yeah super messed
# feed nice
# interesting
# true
# happy easter follow 🐇
# feed yes
# cool
# ok
# tesla amazing 🤣🤣
# murphy nice ink
# cool
# proud
# interesting
# ok
# seeing friends
# yes
# feed engineering ftw
# much appreciated
# feed nice
# fair point
# interesting thread
# thanks 💖
# yes
# true
# yeah
# yeah fate loves irony
# maybe helpful
# sure
# yes
# yes
# true
# good
# sure
# sear definitely
# haha true
# ok fine good haha
# yeah ’ great
# yeah
# definitely
# yes dramatically improved imo
# yes
# bgii amazing
# definitely worth trying imo
# yes
# mcconnell glad ’ ok ❤️
# true pretty impressive
# haha
# mantis ok
# haha
# true
# feeling cute might delete later
# haha true
# ’ welcome fun recruiting event great see excitement helping build starships
# true
# haha
# feed nice
# making progress
# yes
# yes
# haha true
# yes
# nice
# appreciate kind words
# hope ’ enjoying simulation
# foust ok bad
# yes
# nice
# definitely
# ok
# star peace ✌️
# agreed important
# improved accommodations
# yay
# haha
# yes
# yes
# yes
# great song
# haha
# great idea
# correa haha true
# true
# sure
# nice 🤣🤣
# sprockets amazing
# ok
# yes
# haha true
# pretty much
# build super safe earthquakeproof tunnels cities solve traffic
# true
# needs improvement
# yes
# ok sure
# yes 🤣♥️
# great show 🐼
# holiday gift ideas
# ok
# yes
# ok
# yes
# yes
# ’ happy help
# true
# really ok sure
# excellent review marques
# yes
# haha true
# great analysis
# yes
# addicted ryan haha
# fun party guaranteed
# sci true
# true
# congratulations
# haha
# yes
# true
# yes
# yes
# burrough yes
# great poem
# thank helping grow sustainable energy solar
# lu congrats shopify great btw nice work
# haha true
# haha true
# sure
# super proud tesla team great execution amp support tesla customers greatly appreciated
# tesla wins best headlights award 🥇
# addicted yeah great team
# mccomb yep good catch
# haha
# lol
# truth yes
# ’ really quite fun
# yes
# yes
# haha true
# agreed fair point
# sure
# true
# haha yes
# haha awesome
# thanks
# either way sustainable energy wins
# yes
# whoa cool
# nice
# yes
# haha
# yes
# glad ’ ok
# sagan awesome
# haha exactly
# yes
# nawfel sci v2r fun haha
# yes
# dmt ftw
# actually true
# definitely
# wow cool
# rosberg thanks offering sure would great
# nice
# yes
# truth definitely
# haha actually true
# good
# yes
# congrats spacex team
# interesting
# finally vr ’ cool sexy
# sci wow
# yes
# fyi
# true
# support yang
# yes
# sure
# tons fun
# thanks george
# sure
# yes
# yes
# true
# boutall yes
# fates loves irony
# depot haha
# sure
# haha probably true sigh
# ryan yes
# thanks
# feed yes
# starhopper flight successful water towers fly haha
# exciting modes
# true 🤣🤣
# woohoo 🥳
# yes
# 218 🤣🤣 yes security extremely important
# sure
# sure
# great team
# ok
# nice
# agreed
# sounds like fun
# sure
# thanks happy birthday wishes ♥️♥️
# ok
# ok thanks
# overlord98 yeah
# cool
# haha
# anarchosyndicalism ftw
# haha
# fair point
# yeah dual motor awd super fun
# haha
# fun
# strong incentive make amp promote negative news
# yes
# yes
# thoughtful model
# fair
# beautiful solar sail
# great
# ryan would great
# thanks yeah ’ pretty close
# sure
# thanks sam
# boeree ok
# yes
# sure
# congrats many successful launches
# ok
# ok
# yes
# truth
# sure
# gfischer yes
# look like fun
# yes
# p yeah definitely
# true
# ok
# good question
# stop giving away free eth 🤣🤣
# fate loves irony
# jk
# excellent analysis
# og wisdom
# yes
# true
# haha yes
# haha
# strange true
# tesla blows haha
# true
# haha ok
# thanks support super appreciated
# happy home planet day
# 🦆 ftw
# nice
# haha
# haha
# yes
# haha true actually love horses
# yes
# poetic justice
# yes
# yes
# yes
# haha sure sounds like
# love brunel great first
# yes
# ’ welcome thanks great photos
# definitely
# stay positive 🧁
# stevee great 👍
# heats dogecoin might fav cryptocurrency ’ pretty cool
# yes 🐜
# yes
# yes
# seems fair
# duck emoji ftw
# wow
# true
# super cool
# galway good point
# super proud tesla autopilot team
# glad like navigate autopilot hopefully approved europe soon
# thank
# deitsch ’ welcome glad helpful
# sounds like good idea
# agreed win prize
# ryan sure would great
# yes
# true sigh
# true
# true 🤣
# thanks sounds great
# cute
# yes
# yes
# happy birthday
# yes
# haha
# yay
# haha
# thank evelyn loved
# haha true
# yes 😀
# aacarmack agreed
# 😅 thank goodness ’ november
# glad like
# yes
# like nonsense memes ’ true
# yes
# news whoa cool
# yes
# haha
# haha true
# overideal sure hope happens
# enough haha
# yes
# wow
# thanks good idea
# haha ’ welcome hope ’ well
# glad like
# ok
# haha
# tyler yes
# yes
# yes
# yes
# yes 🚀
# aligray yes
# good idea
# great thread 🤣
# obie love tintin
# congratulations
# congratulations team
# thanks
# haha
# haha
# hope everyone happy new year
# ryan happy new year
# yes
# congratulations
# yes
# yep
# yes
# cautillo wow
# thanks hope good holiday insight autonomy excellent
# bowie yes
# glad ’ ok
# haha 🤣
# thanks
# interesting
# yes
# haha
# yes
# congratulations
# yes
# interesting
# glad ’ ok
# haha
# definitely
# haha kinda true 😀
# yes
# congratulations amazing track record success mars
# ah yes fair point
# happy thanksgiving
# yes
# absolutely agree
# haha like super troopers
# tomcross haha 😀
# raul yes
# iost easily accessible energy
# congratulations team thanks much appreciated
# yes
# thecheesy true
# love oumuamua jokes
# ok
# fair
# wow ’ cool
# haha
# yes
# true
# cute
# haha
# hahaha ltahemgt
# yes
# cool haha
# haha
# glad ’ ok
# making progress …
# ok
# love concorde
# yes
# good idea
# yes
# hope true
# special circumstances
# brorsson yes 😀
# yes
# great love princess mononoke
# love
# yes
# station johnson glad ’ safe
# beautiful picture
# ’ welcome glad could helpful thanks letting know
# true
# great verdict 😀
# haha true
# wow glad ’ ok
# yes
# true 😀
# thank trust team greatly appreciated
# interesting
# definitely worth thoughtful debate might differently improve humanlife happiness
# ok
# awesome 😎
# yes
# true
# haha 😀
# yes
# yes
# looks cool
# cool
# sure
# ok
# definitely
# super appreciate free concert tesla intense time 🖤🖤
# great meeting
# amazing
# yes
# good morning 😀
# yes
# definitely
# yes
# yes
# yes
# yes minifloats
# yes
# m0n yes
# yes
# great
# wow ’ really awesome thank ♥️
# haha
# ok
# sure
# wish
# good point
# yes
# interesting read
# happy birthday malala happy support
# sure 🌌 💫
# true
# sounds good
# highroller yeah
# great move
# good point
# great news made safely congratulations outstanding rescue team
# yes
# yes
# ’ welcome happy birthday 🎁🎉🎂
# great thanks
# happy support
# belfast beautiful
# yeah like icp
# wow model ’ cool
# love awesomo
# thanks bill
# oh love trap good suggestions welcome
# sure
# ’ welcome
# yes
# ryan good catch
# yes
# sure
# cool video
# hahaha
# hope kids ok
# wasserman thanks good advice
# yeah think pretty much agree btw great show
# fair point
# writer ok
# lol
# yes
# strongly disagree love humanity
# yes
# love design simpler better
# schmoo yes
# think
# definitely
# glad ’ ok
# sounds like fun adventure
# definitely
# pivac yes
# schiff peace ✌️
# mister yes
# good school
# thanks 😀
# rodriguez ’ great song
# usatoday ftw
# wow amazing tesla hypermile drive happening
# reddit great
# definitely
# yeah think great work
# great idea
# love original deus ex would awesome
# good point
# wanted say thanks tesla supporters damn well love
# yes
# lol
# castillo yes
# happy mother ’ day mom love much
# lovely story
# definitely logo kind
# lol
# super super serious
# yes definitely
# best
# ’ best
# ok
# yes
# thanks
# ok
# yeah find soothing
# yes
# good point
# wsoff great idea
# definitely
# every time alexa laughs angel thank goodness …
# love rockets
# yes
# yes
# sure
# ok
# unless like fun
# great roasting nuts 🔥 🥜
# hogan ok
# mckie ok
# true
# yes
# love twitter
# thanks
# yes
# yeah pretty much anywhere
# yes
# yes
# yes
# yeah
# channel yes
# wow played dampd dampd
# good point
# sure
# hell yeah crew party like escobar cobain wish couldve partied
# yup
# congrats mom love
# deano yes
# yes
# good
# yes
# fun exciting tweets coming soon
# intentionally yes
# played games
# yeah kinda disgusting boys love
# yes
# love kermit
# sure hope
# yes
# yes
# sure
# support would much appreciated
# good point
# yes
# ace11 hopefully
# cool
# cool 😎
# love floors
# thanks looks cool
# cool
# congrats robb
# awesome
# cool
# yes
# yeah
# favorite sure
# yeah
# yeah
# youre welcome
# great comedy write
# great though
# good point
# yeah
# yeah great
# yes
# yes
# true
# something cool sure
# yes
# yes
# anth yes good
# best hopefully yes
# yes
# yes
# good
# great food great ambience great friends really enjoyed visit
# yes
# pretty good
# kent yes
# yes
# yeah
# definitely
# yes
# good point
# ok
# pton16 love wikipedia gets better time
# thanks jj
# thank lovely letter sounds like great idea well
# roller coasters awesome
# good chance
# yeah awesome achievement isro impressive
# yes
# pi yes
# norway great levels love norway
# true
# wish
# wow cool
# lontana nuances important
# world yes
# agree creating great jobs restoring us strength great manufacturer products anything makes future exciting
# yeah sorry
# sigh
# yes
# yes
# good idea
# yes
# yes
# yes
# perfect
# yes
# love
# playing amish paradise tesla
# like humanity
# topgear thanks
# good chance
# yes
# yes
# strongly net positive
# yes
# dear cult members love
# yeah great questions
# bit yes
# with1t yes
# thanks
# sounds like great move
# wow tweet like rorschach test
# yes
# yes
# yeah definitely favorite names
# yeah
# love suggestions
# yes
# true
# glad people great time
# happy birthday
# great game whole fallout series amazing
# much appreciated
# yes
# especially well
# yes
# true good point
# jahn cool thanks
# defense exactly love twitter
# thanks kind bday wishes
# cute
# course love never
# thanks tyler
# yes
# yes
# definitely
# ok
# certainly agree first foremost triumph humanity cheering good spirit
# love
# thank goodness ok
# woohoo
# yes
# yes
# elon yes
# sure
# looks like model x resale value holding well
# thanks
# yes
# favreau thanks
# yes
# yes
# yes
# yes
# sounds good
# hopefully 021
# yes
# cool thanks
# thanks
# sure
# yes
# sure
# sure
# exactly
# hi
# yeah thats great
# yes
# yes
# good point
# interesting
# thanks
# favreau thanks jon
# wow
# best luck cygnus launch
# definitely aliens
# wow thats great
# cool
# thanks bonnie
# yay always happy make others happy
# 8 sure
# yes
# super good
# thanks
# definitely
# yes
# milano thanks alyssa
# thanks loic
# thanks david
# thanks
# youre welcome good conversation
# thanks christie
# haha awesome
# wow
# thanks
# good piece
# good suggestion
# yeah daemon great read
# would happy help
# yes
# agreed
# thanks really appreciate support
# thanks bill sure great start 2014
# true
# rest peace nelson mandela good great
# cool
# agree restored shortly
# thanks
# true
# thanks bill
# youre welcome
# cool
# yes
# good idea
# thanks jeremy good seeing awesome job yelp
# first profitable q tesla thanks awesome customers amp hard work super dedicated team
# yep
# sure
# cool glad like
# nice
# solar array deployment successful
# appreciate thoughtful article faith restored
# great spirit superdome awesome rally sb47
# love indoor flamethrowers
# cute merry xmas
# thanks shervin
# olympics opening excellently british jolly good show
# welcome qwerty monkey jesus love top 5 popular passwords password
# happy bday old dear friend parties better rockstar berlin
# true
#                            0             1             2             3  \
# nlikes          21627.817260  17430.499706  30772.798077  11645.389441
# nreplies          569.939416    449.517322    879.982372    442.394410
# nretweets        2543.221068   1930.529066   4113.144231   1157.395031
# Percent Change      0.008594      0.011005      0.012704      0.012921
# NegScore            0.008148      0.019165      0.368029      0.035666
# NeuScore            0.987688      0.594272      0.545777      0.888123
# PosScore            0.004163      0.386566      0.063750      0.076218
# TeslaFlag           0.000000      0.072578      0.030769      0.300000
# cluster             0.000000      1.000000      2.000000      3.000000
#
#                            4             5
# nlikes          12363.919742  13739.703888
# nreplies          423.403004    352.515454
# nretweets        1630.219742   1316.200399
# Percent Change      0.009914      0.011936
# NegScore            0.056588      0.002972
# NeuScore            0.789489      0.329976
# PosScore            0.153916      0.667051
# TeslaFlag           0.000000      0.037089
# cluster             4.000000      5.000000

# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

from yellowbrick.cluster import InterclusterDistance

# Instantiate the clustering model and visualizer
model = KMeans(n_clusters=n_clusters, n_init=20, n_jobs=4)
visualizer = InterclusterDistance(kmeans)

visualizer.fit(tweets_clust)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure

# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

from yellowbrick.cluster import KElbowVisualizer

# Instantiate the clustering model and visualizer
model = KMeans()
visualizer = KElbowVisualizer(model, k=(2,15))

visualizer.fit(tweets_clust)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure

# %%
from sklearn.cluster import KMeans

from yellowbrick.cluster import SilhouetteVisualizer
from yellowbrick.datasets import load_nfl


# Instantiate the clustering model and visualizer
model = KMeans(n_clusters=n_clusters, n_init=20, n_jobs=4)
visualizer = SilhouetteVisualizer(kmeans, colors='yellowbrick')

visualizer.fit(tweets_clust)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure

# %%
# Imports
import twint
import nest_asyncio
import numpy as np
import pandas as pa
import sklearn as sk
import keras 
import tensorflow as tf
import json
from pandas_datareader import data
from datetime import datetime
from datetime import timedelta  
from pandas.tseries.holiday import USFederalHolidayCalendar
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler

import re
import string

# NLP Packages
import nltk
from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.tokenize import word_tokenize

nltk.download('punkt')
nltk.download('vader_lexicon')
nltk.download('stopwords')

# This ensures the twint loop can run in jupyter notebook, no need to understand it
nest_asyncio.apply()
pa.set_option('display.max_colwidth', None)

# Predetermined Parameters
user = "elonmusk"
tckr = "TSLA"

# Use twint to grab tweets and put into pandas dataframe
c = twint.Config()

c.Username = user
# I don't think the following line is neccessary as inputting to pandas gives us all columns by default
c.Custom["tweet"] = ["id", "username", "created_at", "username", "mentions" , "replies_count", "retweets_count", "likes_count", "hashtags", "tweet"]
c.Pandas = True

twint.run.Search(c)

Tweets_df = twint.storage.panda.Tweets_df

# Show dataframe
Tweets_df

#  Show columns of dataframe
data_cols = Tweets_df.columns  
    
# display  
data_cols  

# Get rid of tweets that are just replies (debatable for futre, we can test)
inds = []
col = Tweets_df['reply_to']
for i in range(Tweets_df.shape[0]):
    x = col[i]
    if x:
        inds.append(i)
# print(inds)
Tweets_df = Tweets_df.drop(inds, inplace = False)
Tweets_df

# Remove undesirable columns
rems = ['id', 'conversation_id', 'created_at', 'timezone', 'place',
       'language', 'user_id',
       'username', 'name', 'day', 'hour', 'urls', 'photos', 'video',
       'thumbnail', 'quote_url', 'search',
       'near', 'geo', 'source', 'reply_to', 'translate', 'trans_src',
       'trans_dest', 'link', 'user_id_str', 'cashtags']
Rem_Cols = Tweets_df.drop(rems, inplace = False, axis=1)
Rem_Cols.reset_index(drop=True, inplace=True)
Rem_Cols

# Get stock data in range we will be using (calling yahoo once for a set of data that contains unwated values is far more efficient, trust me)
col = Rem_Cols['date']
# print(col)
end1 = (datetime.strptime(col[0], '%Y-%m-%d %H:%M:%S') + timedelta(days=3)).date()
start1 = (datetime.strptime(col[Rem_Cols.shape[0]-1], '%Y-%m-%d %H:%M:%S') + timedelta(days=-7)).date()

end = (datetime.strptime(col[0], '%Y-%m-%d %H:%M:%S') + timedelta(days=3)).date().strftime('%Y-%m-%d')
start = (datetime.strptime(col[Rem_Cols.shape[0]-1], '%Y-%m-%d %H:%M:%S') + timedelta(days=-7)).date().strftime('%Y-%m-%d')
panel_data = data.DataReader(tckr, 'yahoo', start, end)["Adj Close"]

inds = []
keys = panel_data.keys()
col = Rem_Cols['date']
for i in range(Rem_Cols.shape[0]):
    x = col[i]
    # print(datetime.strptime(x, '%Y-%m-%d %H:%M:%S') < keys[0])
    if (datetime.strptime(x, '%Y-%m-%d %H:%M:%S') < keys[0] or datetime.strptime(x, '%Y-%m-%d %H:%M:%S') > (datetime.today() + timedelta(days=-3))):
        inds.append(i)
tweets = Rem_Cols.drop(inds, inplace = False, axis=0)
# print(panel_data[end])
tweets.reset_index(drop=True, inplace=True)
tweets

# Acquire percent change of the closing prices surrounding each tweet and add to dataframe
percs = []
col = tweets['date']
for i in range(tweets.shape[0]):
    x = col[i]
    end_date = datetime.strptime(x, '%Y-%m-%d %H:%M:%S')

    if (end_date.hour > 15):
        end_date = end_date + timedelta(days=1)
    start_date = end_date + timedelta(days=-1)

    while (end_date.date() not in panel_data) or (end_date.weekday() == 5) or (end_date.weekday() == 6):
        end_date = end_date + timedelta(days=1) 
    while (start_date.date() not in panel_data) or (start_date.weekday() == 5) or (start_date.weekday() == 6):
        start_date = start_date + timedelta(days=-1)
    end_date = end_date.date().strftime('%Y-%m-%d')
    start_date = start_date.date().strftime('%Y-%m-%d')
    percs.append((panel_data[end_date] - panel_data[start_date])/panel_data[start_date])

tweets['Percent Change'] = percs
tweets

# Tweet cleaning helper methods
def cleanTxt(text):
    # Get rid of @s, links, Hashtag, and RT
    text = re.sub(r'@[A-Za-z0-9]+', '', str(text))
    text = re.sub(r'#', '', str(text))
    text = re.sub(r'RT[\s]+', '', str(text))
    text = re.sub(r'https?:\/\/\S+', '', str(text))

    # Lowercase and remove punctuation
    text = text.lower()
    text = text.translate(str.maketrans('', '', string.punctuation))

    tokens = word_tokenize(text)
    tokens_without_sw = [word for word in tokens if word not in stopwords.words()]
    return " ".join(tokens_without_sw)

tweets['tweet'] = tweets['tweet'].apply(cleanTxt)
# tweets['tweet'] = tweets['tweet'].apply(removeStopWords)
tweets

# Sentiment score helpers
def sentimentScoreNeg(text):
    score = SentimentIntensityAnalyzer().polarity_scores(text)
    return score['neg']

def sentimentScorePos(text):
    score = SentimentIntensityAnalyzer().polarity_scores(text)
    return score['pos']

def sentimentScoreNeu(text):
    score = SentimentIntensityAnalyzer().polarity_scores(text)
    return score['neu']
tweets

tweets['NegScore'] = tweets['tweet'].apply(sentimentScoreNeg)
tweets['NeuScore'] = tweets['tweet'].apply(sentimentScoreNeu)
tweets['PosScore'] = tweets['tweet'].apply(sentimentScorePos)
tweets

# Determine if tweet is about tesla
def isAboutTesla(text):
    flag = 0
    myList = ["Tesla" in text, "tesla" in text, "TESLA" in text, "TSLA" in text]

    if any(myList):
        flag = .3

    return flag

tweets['TeslaFlag'] = tweets['tweet'].apply(isAboutTesla)
tweets

# for i in range(tweets.shape[0]):
#     print(tweets['tweet'][i])
cleaned_tweets = tweets['tweet'].apply(cleanTxt)
tweets.drop(['date', 'tweet', 'hashtags'], inplace = True, axis=1)
tweets

cleaned_tweets

# Create clear cut clusters for positive v negative change
def percChangeAssign(perc):
    if perc >= 0:
        return 1
    else:
        return 0

tweets_edit = tweets.copy()
tweets_edit['Percent Change'] = tweets_edit['Percent Change'].apply(percChangeAssign)
tweets

tweets_clust = tweets_edit.copy()
scaler = MinMaxScaler(feature_range=(0,1))
nlikes = scaler.fit_transform(tweets_clust['nlikes'].values.reshape(-1,1))
tweets_clust['nlikes'] = nlikes
nreplies = scaler.fit_transform(tweets_clust['nreplies'].values.reshape(-1,1))
tweets_clust['nreplies'] = nreplies
nretweets = scaler.fit_transform(tweets_clust['nretweets'].values.reshape(-1,1))
tweets_clust['nretweets'] = nretweets
scaler = MinMaxScaler(feature_range=(0,1))
neg = scaler.fit_transform(tweets_clust['NegScore'].values.reshape(-1,1))
tweets_clust['NegScore'] = neg
neu = scaler.fit_transform(tweets_clust['NeuScore'].values.reshape(-1,1))
tweets_clust['NeuScore'] = neu
pos = scaler.fit_transform(tweets_clust['PosScore'].values.reshape(-1,1))
tweets_clust['PosScore'] = pos
tweets_clust

# Grab the "Answers"
answers = tweets_clust['Percent Change'].values
print(answers)
tweets_clust.drop(['Percent Change'], inplace = True, axis=1)
tweets_clust

n_clusters = 6
# len(np.unique(y))

kmeans = KMeans(n_clusters=n_clusters, n_init=20, n_jobs=4)
# Train K-Means.
y_pred_kmeans = kmeans.fit(tweets_clust)
y_pred_kmeans = kmeans.predict(tweets_clust)
# Evaluate the K-Means clustering accuracy.
# metrics.acc(y, y_pred_kmeans)
num = 11313
print(y_pred_kmeans)
print(answers)
if n_clusters == 2:
    print(np.sum(y_pred_kmeans[0:num]))
    print(np.sum(answers[0:num]))
    print(sk.metrics.accuracy_score(answers[0:num], y_pred_kmeans[0:num]))
    print(sk.metrics.recall_score(answers[0:num], y_pred_kmeans[0:num]))
    print(sk.metrics.precision_score(answers[0:num], y_pred_kmeans[0:num]))
tweets_results = tweets.copy()
tweets_results['cluster'] = y_pred_kmeans
tweets_results

clust_0 = tweets_results.loc[tweets_results['cluster'] == 0] 
inds = clust_0.index
print("")
print("")
print("")
print("")
print("Clust ", 0)
for j in inds:
    print(cleaned_tweets[j])
clusts = pa.DataFrame(data=clust_0.mean(axis=0))
for i in range(1,n_clusters):
    clust_i = tweets_results.loc[tweets_results['cluster'] == i] 
    inds = clust_i.index
    print("")
    print("")
    print("")
    print("")
    print("Clust ", i)
    for j in inds:
        print(cleaned_tweets[j])
    # clust_1 = tweets_results.loc[tweets_results['cluster'] == 1]
    # clust_2 = tweets_results.loc[tweets_results['cluster'] == 2] 
    # clust_3 = tweets_results.loc[tweets_results['cluster'] == 3]
    # clust_4 = tweets_results.loc[tweets_results['cluster'] == 4] 
    # clust_5 = tweets_results.loc[tweets_results['cluster'] == 5]
    # print("Cluster 0\n", clust_0.shape, "\n",clust_0.mean(axis=0))
    # print("Cluster 1\n", clust_1.shape, "\n",clust_1.mean(axis=0))
    # print("Cluster 2\n", clust_2.shape, "\n",clust_2.mean(axis=0))
    # print("Cluster 3\n", clust_3.shape, "\n",clust_3.mean(axis=0))
    # print("Cluster 4\n", clust_4.shape, "\n",clust_4.mean(axis=0))
    # print("Cluster 5\n", clust_5.shape, "\n",clust_5.mean(axis=0))
    
    clusts[i] = clust_i.mean(axis=0)
clusts

from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

from yellowbrick.cluster import InterclusterDistance

# Instantiate the clustering model and visualizer
model = KMeans(n_clusters=n_clusters, n_init=20, n_jobs=4)
visualizer = InterclusterDistance(kmeans)

visualizer.fit(tweets_clust)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure

from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

from yellowbrick.cluster import KElbowVisualizer

# Instantiate the clustering model and visualizer
model = KMeans()
visualizer = KElbowVisualizer(model, k=(2,15))

visualizer.fit(tweets_clust)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure

from sklearn.cluster import KMeans

from yellowbrick.cluster import SilhouetteVisualizer
from yellowbrick.datasets import load_nfl


# Instantiate the clustering model and visualizer
model = KMeans(n_clusters=n_clusters, n_init=20, n_jobs=4)
visualizer = SilhouetteVisualizer(kmeans, colors='yellowbrick')

visualizer.fit(tweets_clust)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure
